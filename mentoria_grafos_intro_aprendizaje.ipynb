# %% [markdown]
# # Análisis y visualización de datos
#
# Con el objetivo de ir entendiendo la naturaleza de los datos y su modo de presentación de grafos, vamos a ir analizando los distintos tipos de nodos con sus características.
#
# Se puede comenzar por los siguientes puntos y luego agregar otros de interés:
#
# 1- Cantidad de Personas por Edades, aqui podemos analizar la distribución de las personas de todos los equipos de trabajo, otro análisis que se puede realizar es determinar el mismo análisis pero separado por sexo.
#
# 2- Existe otro factor importante para determinar el grado de conocimiento determinado por su Seniority (organizados como Senior, Semi-senior y Junior, siendo este último el de menos experiencia), aqui podemos determinar el nivel de expertís sobre las tecnologías a analizar y con ello determinar si los equipos están altamente especializados con perfiles senior o balancean su capacidad de trabajo con perfiles de menos experiencia.
# Otro factor importante a analizar es el grado de participación de las mujeres ya que de esta manera se pueden aumentar la participación de mujeres en caso de que sea muy escasa.
#
# 3- Se correlacionan las edades de las personas con los años de experiencia, que nivel de participación se observa por sexo?
#
# 4- Cuales con los conocimientos que más poseen las personas?
# Teniendo en cuenta que más adelante queremos equilibrar los conocimientos que tecnologias son las dominantes? , que nivel de participación se observa por sexo?
#
# No olvidar responder a los puntos anteriores también con las visualizaciones apropiadas.
#
# Tip: una visualización interesante para la frecuencia de palabras es la WordCloud.

# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

import numpy as np

import matplotlib as mpl
mpl.get_cachedir()
import matplotlib.pyplot as plt

import sklearn
import sklearn.datasets
import sklearn.linear_model
import sklearn.neural_network

import utils

# %%
#Lectura
# Vamos a abrir los archivos que poseen la información
# El primer archivo posee los nodos que contienen a las personas, skills, conocimientos, team  (como se explicó en el dataset)
# Aqui se encuentran todos los features de acuerdo al tipo de nodo
nodos = pd.read_csv(
    'https://raw.githubusercontent.com/fgpalacios/diplodatos2020/master/dataset/nodes.csv')

# El segundo archivo posee la relación que existen entre los nodos es decir un nodo persona tiene conocimientos vinculados que es lo que sabe
relaciones = pd.read_csv(
    'https://raw.githubusercontent.com/fgpalacios/diplodatos2020/master/dataset/relationships.csv')

#Display HTML
display(nodos.head())
display(relaciones.head())
# Out:
#                                                 n.id name_node_a  n.type  \
# 0  eeca1815ef2efc089f12bfe8c1c4c7f7-c81e728d9d4c2...       Team3    team
# 1  73cceb4a6d1f1fd7e91d38c2b906be15-c81e728d9d4c2...       Team2    team
# 2  1ae7f988daa7541df8d9eba692e3949d-c81e728d9d4c2...     Marcela  person
# 3  f496c7004f07dba853bf8fadc28c9650-c81e728d9d4c2...      Daniel  person
# 4  e726642e86168eacfeee3fa8c4da012e-c81e728d9d4c2...    Leonardo  person
#
#   n.category n.gender  n.age  n.experience
# 0        NaN      NaN    0.0           NaN
# 1        NaN      NaN    0.0           NaN
# 2     junior   female   23.0           3.0
# 3     senior     male   44.0          11.0
# 4     senior     male   45.0          16.0
#                                            id_node_a name_node_a  \
# 0  eeca1815ef2efc089f12bfe8c1c4c7f7-c81e728d9d4c2...       Team3
# 1  eeca1815ef2efc089f12bfe8c1c4c7f7-c81e728d9d4c2...       Team3
# 2  eeca1815ef2efc089f12bfe8c1c4c7f7-c81e728d9d4c2...       Team3
# 3  73cceb4a6d1f1fd7e91d38c2b906be15-c81e728d9d4c2...       Team2
# 4  73cceb4a6d1f1fd7e91d38c2b906be15-c81e728d9d4c2...       Team2
#
#                                            id_node_b name_node_b  \
# 0  f496c7004f07dba853bf8fadc28c9650-c81e728d9d4c2...      Daniel
# 1  1ae7f988daa7541df8d9eba692e3949d-c81e728d9d4c2...     Marcela
# 2  a5b6fc8ad5a79c2b57af4137389a7b6b-c81e728d9d4c2...     Marcelo
# 3  e726642e86168eacfeee3fa8c4da012e-c81e728d9d4c2...    Leonardo
# 4  10c246e19e023f335e179b937c28a6da-c81e728d9d4c2...      Matias
#
#                                      id_relationship
# 0  78031203cb9f8df3b96024f973e93dce-c81e728d9d4c2...
# 1  920da6fdbb28002170bd11ac31f931fa-c81e728d9d4c2...
# 2  d5f338d4f13a96698fda12514a76e4ad-c81e728d9d4c2...
# 3  bad0c7e4278c68df0eeadaaa9499f260-c81e728d9d4c2...
# 4  ff8fe587c76f4587b2fe3c6a4bd98d86-c81e728d9d4c2...

# %% [markdown]
# # Generamos estadísticas descriptivas del nodo.

# %%
nodos.describe()
# Out:
#            n.age  n.experience
# count  22.000000     14.000000
# mean   20.681818      5.785714
# std    16.980062      4.281958
# min     0.000000      2.000000
# 25%     0.000000      3.000000
# 50%    26.000000      4.000000
# 75%    34.000000      6.750000
# max    45.000000     16.000000

# %%
nodos.columns
# Out:
# Index(['n.id', 'name_node_a', 'n.type', 'n.category', 'n.gender', 'n.age',
#        'n.experience'],
#       dtype='object')

# %% [markdown]
# Analizamos los tipos de datos de cada campo inferidos por panda de los nodos

# %%
# En el caso de querer trabajar solo con las personas se puede aplicar lo siguiente:
#Drop Nodos que no sean personas
personas = nodos[nodos["n.type"] == "person"]

#Display html
display(personas)
# Out:
#                                                  n.id name_node_a  n.type  \
# 2   1ae7f988daa7541df8d9eba692e3949d-c81e728d9d4c2...     Marcela  person
# 3   f496c7004f07dba853bf8fadc28c9650-c81e728d9d4c2...      Daniel  person
# 4   e726642e86168eacfeee3fa8c4da012e-c81e728d9d4c2...    Leonardo  person
# 5   10c246e19e023f335e179b937c28a6da-c81e728d9d4c2...      Matias  person
# 6   bcb93d9680b08656367b3682a9b4c127-c81e728d9d4c2...      Lionel  person
# 7   f9fdac801645d8b673ce785f01658a1e-c81e728d9d4c2...      Miguel  person
# 8   822736b3fe21296f7d5c35a5e13d3ca3-c81e728d9d4c2...     Luciana  person
# 9   a5b6fc8ad5a79c2b57af4137389a7b6b-c81e728d9d4c2...     Marcelo  person
# 18  79b60482d282d7fe48287ef484be2d31-a87ff679a2f3e...     Jonatan  person
# 19  6bb28c0af81044a5f2bf023eb7f253e2-a87ff679a2f3e...       Lucas  person
# 20  51280652ee54bf9e25636110b859faf5-a87ff679a2f3e...    Fernando  person
# 21  f6b8790fd8dcb51f4ccec2e19f6db824-a87ff679a2f3e...      Gastón  person
# 22  533348a1f755b9512eb8b91aa07a300a-a87ff679a2f3e...      Andrea  person
# 23  8ebb5bf7f39a9ec7304a17cdf5063df9-a87ff679a2f3e...      Martin  person
#
#      n.category n.gender  n.age  n.experience
# 2        junior   female   23.0           3.0
# 3        senior     male   44.0          11.0
# 4        senior     male   45.0          16.0
# 5        junior     male   25.0           2.0
# 6   semi-senior     male   35.0           3.0
# 7        junior     male   24.0           2.0
# 8   semi-senior   female   34.0           4.0
# 9        senior     male   41.0          12.0
# 18       senior     male   33.0           7.0
# 19       senior     male   35.0           6.0
# 20  semi-senior     male   28.0           4.0
# 21  semi-senior     male   27.0           3.0
# 22  semi-senior   female   27.0           3.0
# 23       senior     male   34.0           5.0

# %%
dtypes = pd.DataFrame(personas.dtypes)
dtypes.index.name = 'Campo'
dtypes.rename(columns={0: 'Tipo'})
# Out:
#                  Tipo
# Campo
# n.id           object
# name_node_a    object
# n.type         object
# n.category     object
# n.gender       object
# n.age         float64
# n.experience  float64

# %% [markdown]
# Analizamos los tipos de datos de cada campo inferidos por pandas de las relaciones

# %%
# Generamos estadísticas descriptivas de las relaciones
relaciones.describe()
# Out:
#                                                 id_node_a name_node_a  \
# count                                                 197         197
# unique                                                 64          64
# top     f496c7004f07dba853bf8fadc28c9650-c81e728d9d4c2...      Daniel
# freq                                                   15          15
#
#                                                 id_node_b name_node_b  \
# count                                                 197         197
# unique                                                 70          69
# top     2320e632b8e006a33216f6b3a1c78578-a87ff679a2f3e...  SQL Server
# freq                                                   12          12
#
#                                           id_relationship
# count                                                 197
# unique                                                197
# top     a9ffe67859eda99fe2cec42d54f27433-c81e728d9d4c2...
# freq                                                    1

# %%
dtypes = pd.DataFrame(relaciones.dtypes)
dtypes.index.name = 'Campo'
dtypes.rename(columns={0: 'Tipo'})
# Out:
#                    Tipo
# Campo
# id_node_a        object
# name_node_a      object
# id_node_b        object
# name_node_b      object
# id_relationship  object

# %% [markdown]
# Vamos a necesitar conocer los tipos de datos en caso de querer trabajar con el dataset de personas

# %%
personas.describe()
# Out:
# Campo      n.age  n.experience
# count  14.000000     14.000000
# mean   32.500000      5.785714
# std     7.219099      4.281958
# min    23.000000      2.000000
# 25%    27.000000      3.000000
# 50%    33.500000      4.000000
# 75%    35.000000      6.750000
# max    45.000000     16.000000

# %% [markdown]
# Para visualizar la distribución de las edades

# %%
import seaborn as sns
sns.distplot(personas['n.age'], kde=True);

# %% [markdown]
# Para calcular la probabilidad de los valores posibles sexo y seniority (category), una forma más sencilla con la operación value_counts de pandas.

# %%
data = personas['n.gender'].value_counts(normalize=True).reset_index()
data
# Out:
#     index  n.gender
# 0    male  0.785714
# 1  female  0.214286

# %%
data = personas['n.category'].value_counts(normalize=True).reset_index()
data
# Out:
#          index  n.category
# 0       senior    0.428571
# 1  semi-senior    0.357143
# 2       junior    0.214286

# %% [markdown]
# Para poder trabajar con ambos dataset necesitamos hacer lo siguiente

# %%
resultante = nodos.merge(relaciones, left_on='n.id', right_on='id_node_a')

# %%
display(resultante.head())
# Out:
# Campo                                               n.id name_node_a_x n.type  \
# 0      eeca1815ef2efc089f12bfe8c1c4c7f7-c81e728d9d4c2...         Team3   team
# 1      eeca1815ef2efc089f12bfe8c1c4c7f7-c81e728d9d4c2...         Team3   team
# 2      eeca1815ef2efc089f12bfe8c1c4c7f7-c81e728d9d4c2...         Team3   team
# 3      73cceb4a6d1f1fd7e91d38c2b906be15-c81e728d9d4c2...         Team2   team
# 4      73cceb4a6d1f1fd7e91d38c2b906be15-c81e728d9d4c2...         Team2   team
#
# Campo n.category n.gender  n.age  n.experience  \
# 0            NaN      NaN    0.0           NaN
# 1            NaN      NaN    0.0           NaN
# 2            NaN      NaN    0.0           NaN
# 3            NaN      NaN    0.0           NaN
# 4            NaN      NaN    0.0           NaN
#
# Campo                                          id_node_a name_node_a_y  \
# 0      eeca1815ef2efc089f12bfe8c1c4c7f7-c81e728d9d4c2...         Team3
# 1      eeca1815ef2efc089f12bfe8c1c4c7f7-c81e728d9d4c2...         Team3
# 2      eeca1815ef2efc089f12bfe8c1c4c7f7-c81e728d9d4c2...         Team3
# 3      73cceb4a6d1f1fd7e91d38c2b906be15-c81e728d9d4c2...         Team2
# 4      73cceb4a6d1f1fd7e91d38c2b906be15-c81e728d9d4c2...         Team2
#
# Campo                                          id_node_b name_node_b  \
# 0      f496c7004f07dba853bf8fadc28c9650-c81e728d9d4c2...      Daniel
# 1      1ae7f988daa7541df8d9eba692e3949d-c81e728d9d4c2...     Marcela
# 2      a5b6fc8ad5a79c2b57af4137389a7b6b-c81e728d9d4c2...     Marcelo
# 3      e726642e86168eacfeee3fa8c4da012e-c81e728d9d4c2...    Leonardo
# 4      10c246e19e023f335e179b937c28a6da-c81e728d9d4c2...      Matias
#
# Campo                                    id_relationship
# 0      78031203cb9f8df3b96024f973e93dce-c81e728d9d4c2...
# 1      920da6fdbb28002170bd11ac31f931fa-c81e728d9d4c2...
# 2      d5f338d4f13a96698fda12514a76e4ad-c81e728d9d4c2...
# 3      bad0c7e4278c68df0eeadaaa9499f260-c81e728d9d4c2...
# 4      ff8fe587c76f4587b2fe3c6a4bd98d86-c81e728d9d4c2...

# %% [markdown]
# Si queremos trabajar con las colunmas de padre e hijo de esta primer relación

# %%
resultante[resultante['n.type']=='person'][['n.category','name_node_a_y','name_node_b']]
# Out:
# Campo n.category name_node_a_y     name_node_b
# 8         junior       Marcela       Developer
# 9         junior       Marcela         windows
# 10        junior       Marcela           Linux
# 11        junior       Marcela           MySQL
# 12        junior       Marcela          phyton
# ..           ...           ...             ...
# 118       senior        Martin  Data Scientist
# 119       senior        Martin         Vertica
# 120       senior        Martin      SQL Server
# 121       senior        Martin          phyton
# 122       senior        Martin             ODI
#
# [106 rows x 3 columns]

# %% [markdown]
# # Análisis exploratorio y curación de datos
# En ésta entrega se comenzará a preparar el dataset para los prácticos siguientes. Algunos puntos de aquí ya han sido cubiertos en la entrega anterior para hacer el análisis. Otros pueden tener un tratamiento especial según nuestro enfoque de NLP.\
#
# ## Listado de puntos a cubrir en análisis y curación:
#
# a. Asegurarse de tener ids/claves únicas\
# b. Chequear que no haya datos duplicados\
# c. No usar caracteres especiales en las etiquetas de variables\
# d. Verificar que no haya problemas de codificación/encoding\
# e. Verificar la consistencia de las variables\
# f. Identificar y documentar valores atípicos/outliers. Qué outliers pueden haberse encontrado en el análisis del práctico previo?\
# g. Tratar valores faltantes: quitar o imputar. En éste caso, se correspondería tambien con buscar si hay conversaciones vacías, y quitarlas ya que no aportarían nada a los prácticos siguientes\
# h. Codificar variables: las variables categóricas deben ser etiquetadas como variables numéricas, no como cadenas. Aquí ya se puede empezar a pensar en vectorizar las frases para los prácticos posteriores.\
# Con los puntos anteriores ya se puede preparar los datasets que vamos a usar más adelante.\
#
# DATASET1- Preparar un dataset para usar modelos supervisados. Éste debe incluir las personas, los conocimientos, los perfiles (skills) opcional (los teams), que son las que se van a usar para en armar una regresión lineal sobre las personas con los años de experiencias vs el ranking que posee de sus conocimientos.\
#
# DATASET2- Preparar el dataset para el práctico de aprendizaje no supervisado. Éste está orientado a descubrir dentificar los perfiles que puede poseer cada persona, en base a ciertas personas ya clasificadas, por lo que en éste caso debe filtrar éste subconjunto de perfiles (Skills).\
#
# Por último, guarde los datasets en un formato conveniente para usar después. Importante: guardarlos en nuevos archivos para no sobreescribir los datos crudos u originales\

# %%
nodos_ = nodos
relaciones_ = relaciones

# %% [markdown]
# a.

# %%
nodos.shape
# Out:
# (92, 7)

# %%
relaciones.shape
# Out:
# (197, 5)

# %%
nodos.columns
nodos_col = nodos.columns

# %%
relaciones.columns
relaciones_col = relaciones.columns

# %%
pd.Series(nodos.index, dtype=str).describe()
# Out:
# count     92
# unique    92
# top       15
# freq       1
# dtype: object

# %%
nodos[nodos.index.duplicated()]
# Out:
# Empty DataFrame
# Columns: [n.id, name_node_a, n.type, n.category, n.gender, n.age, n.experience]
# Index: []

# %%
pd.Series(relaciones.index, dtype=str).describe()
# Out:
# count     197
# unique    197
# top       141
# freq        1
# dtype: object

# %%
relaciones[relaciones.index.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id_node_a, name_node_a, id_node_b, name_node_b, id_relationship]
# Index: []

# %% [markdown]
# Conclusión: no hay índices/ids/claves duplicados.

# %% [markdown]
# b.

# %%
nodos[nodos.duplicated()]
# Out:
# Empty DataFrame
# Columns: [n.id, name_node_a, n.type, n.category, n.gender, n.age, n.experience]
# Index: []

# %%
relaciones[relaciones.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id_node_a, name_node_a, id_node_b, name_node_b, id_relationship]
# Index: []

# %% [markdown]
# Conclusión: no hay datos duplicados.

# %% [markdown]
# c.

# %%
display(nodos.columns[~nodos.columns.str.match(r'^(\w+)$')])
# Out:
# Index(['n.id', 'n.type', 'n.category', 'n.gender', 'n.age', 'n.experience'], dtype='object', name='Campo')

# %%
nodos.columns = nodos.columns.str.replace('.', '_')
nodos.head()
# Out:
# Campo                                               n_id name_node_a  n_type  \
# 0      eeca1815ef2efc089f12bfe8c1c4c7f7-c81e728d9d4c2...       Team3    team
# 1      73cceb4a6d1f1fd7e91d38c2b906be15-c81e728d9d4c2...       Team2    team
# 2      1ae7f988daa7541df8d9eba692e3949d-c81e728d9d4c2...     Marcela  person
# 3      f496c7004f07dba853bf8fadc28c9650-c81e728d9d4c2...      Daniel  person
# 4      e726642e86168eacfeee3fa8c4da012e-c81e728d9d4c2...    Leonardo  person
#
# Campo n_category n_gender  n_age  n_experience
# 0            NaN      NaN    0.0           NaN
# 1            NaN      NaN    0.0           NaN
# 2         junior   female   23.0           3.0
# 3         senior     male   44.0          11.0
# 4         senior     male   45.0          16.0

# %%
display(relaciones.columns[~relaciones.columns.str.match(r'^(\w+)$')])
# Out:
# Index([], dtype='object', name='Campo')

# %% [markdown]
# d.

# %%
# helpful character encoding module
import chardet
import string

# %%
# look at the first ten thousand bytes to guess the character encoding
with open('nodes.csv', 'rb') as rawdata_nodos:
    result = chardet.detect(rawdata_nodos.read(1000))

# check what the character encoding might be
result
# Out:
# {'encoding': 'UTF-8-SIG', 'confidence': 1.0, 'language': ''}

# %%
# look at the first ten thousand bytes to guess the character encoding
with open('relationships.csv', 'rb') as rawdata_nodos:
    result = chardet.detect(rawdata_nodos.read(1000))

# check what the character encoding might be
result
# Out:
# {'encoding': 'UTF-8-SIG', 'confidence': 1.0, 'language': ''}

# %% [markdown]
# conclusión: Usa un cifrado standard con un 100% de confianza.

# %%
import ftfy.badness as bad

# %%
def weird(val):
    if isinstance(val, float): 
        return 0
    return bad.sequence_weirdness(val)

# %%
for c in nodos.columns:
    name = c+'weirdness'
    nodos[name] = nodos[c].apply(weird)
    print(nodos[nodos[name] > 1].count())
# Out:
# Campo
# n_id             0
# name_node_a      0
# n_type           0
# n_category       0
# n_gender         0
# n_age            0
# n_experience     0
# n_idweirdness    0
# dtype: int64
# Campo
# n_id                    0
# name_node_a             0
# n_type                  0
# n_category              0
# n_gender                0
# n_age                   0
# n_experience            0
# n_idweirdness           0
# name_node_aweirdness    0
# dtype: int64
# Campo
# n_id                    0
# name_node_a             0
# n_type                  0
# n_category              0
# n_gender                0
# n_age                   0
# n_experience            0
# n_idweirdness           0
# name_node_aweirdness    0
# n_typeweirdness         0
# dtype: int64
# Campo
# n_id                    0
# name_node_a             0
# n_type                  0
# n_category              0
# n_gender                0
# n_age                   0
# n_experience            0
# n_idweirdness           0
# name_node_aweirdness    0
# n_typeweirdness         0
# n_categoryweirdness     0
# dtype: int64
# Campo
# n_id                    0
# name_node_a             0
# n_type                  0
# n_category              0
# n_gender                0
# n_age                   0
# n_experience            0
# n_idweirdness           0
# name_node_aweirdness    0
# n_typeweirdness         0
# n_categoryweirdness     0
# n_genderweirdness       0
# dtype: int64
# Campo
# n_id                    0
# name_node_a             0
# n_type                  0
# n_category              0
# n_gender                0
# n_age                   0
# n_experience            0
# n_idweirdness           0
# name_node_aweirdness    0
# n_typeweirdness         0
# n_categoryweirdness     0
# n_genderweirdness       0
# n_ageweirdness          0
# dtype: int64
# Campo
# n_id                     0
# name_node_a              0
# n_type                   0
# n_category               0
# n_gender                 0
# n_age                    0
# n_experience             0
# n_idweirdness            0
# name_node_aweirdness     0
# n_typeweirdness          0
# n_categoryweirdness      0
# n_genderweirdness        0
# n_ageweirdness           0
# n_experienceweirdness    0
# dtype: int64

# %%
for c in relaciones.columns:
    name = c+'weirdness'
    relaciones[name] = relaciones[c].apply(weird)
    print(relaciones[relaciones[name] > 1].count())
# Out:
# Campo
# id_node_a             0
# name_node_a           0
# id_node_b             0
# name_node_b           0
# id_relationship       0
# id_node_aweirdness    0
# dtype: int64
# Campo
# id_node_a               0
# name_node_a             0
# id_node_b               0
# name_node_b             0
# id_relationship         0
# id_node_aweirdness      0
# name_node_aweirdness    0
# dtype: int64
# Campo
# id_node_a               0
# name_node_a             0
# id_node_b               0
# name_node_b             0
# id_relationship         0
# id_node_aweirdness      0
# name_node_aweirdness    0
# id_node_bweirdness      0
# dtype: int64
# Campo
# id_node_a               0
# name_node_a             0
# id_node_b               0
# name_node_b             0
# id_relationship         0
# id_node_aweirdness      0
# name_node_aweirdness    0
# id_node_bweirdness      0
# name_node_bweirdness    0
# dtype: int64
# Campo
# id_node_a                   0
# name_node_a                 0
# id_node_b                   0
# name_node_b                 0
# id_relationship             0
# id_node_aweirdness          0
# name_node_aweirdness        0
# id_node_bweirdness          0
# name_node_bweirdness        0
# id_relationshipweirdness    0
# dtype: int64

# %% [markdown]
# e.

# %%
nodos.head()
# Out:
# Campo                                               n_id name_node_a  n_type  \
# 0      eeca1815ef2efc089f12bfe8c1c4c7f7-c81e728d9d4c2...       Team3    team
# 1      73cceb4a6d1f1fd7e91d38c2b906be15-c81e728d9d4c2...       Team2    team
# 2      1ae7f988daa7541df8d9eba692e3949d-c81e728d9d4c2...     Marcela  person
# 3      f496c7004f07dba853bf8fadc28c9650-c81e728d9d4c2...      Daniel  person
# 4      e726642e86168eacfeee3fa8c4da012e-c81e728d9d4c2...    Leonardo  person
#
# Campo n_category n_gender  n_age  n_experience  n_idweirdness  \
# 0            NaN      NaN    0.0           NaN              0
# 1            NaN      NaN    0.0           NaN              0
# 2         junior   female   23.0           3.0              0
# 3         senior     male   44.0          11.0              0
# 4         senior     male   45.0          16.0              0
#
# Campo  name_node_aweirdness  n_typeweirdness  n_categoryweirdness  \
# 0                         0                0                    0
# 1                         0                0                    0
# 2                         0                0                    0
# 3                         0                0                    0
# 4                         0                0                    0
#
# Campo  n_genderweirdness  n_ageweirdness  n_experienceweirdness
# 0                      0               0                      0
# 1                      0               0                      0
# 2                      0               0                      0
# 3                      0               0                      0
# 4                      0               0                      0

# %%
nodos[(nodos.n_type == 'team') & (nodos.n_age != 0)]
# Out:
# Empty DataFrame
# Columns: [n_id, name_node_a, n_type, n_category, n_gender, n_age, n_experience, n_idweirdness, name_node_aweirdness, n_typeweirdness, n_categoryweirdness, n_genderweirdness, n_ageweirdness, n_experienceweirdness]
# Index: []

# %%
nodos[(nodos.n_type == 'person') & (nodos.n_age == 0)]
# Out:
# Empty DataFrame
# Columns: [n_id, name_node_a, n_type, n_category, n_gender, n_age, n_experience, n_idweirdness, name_node_aweirdness, n_typeweirdness, n_categoryweirdness, n_genderweirdness, n_ageweirdness, n_experienceweirdness]
# Index: []

# %%
nodos[(nodos.n_type == "person") & (nodos.n_age < nodos.n_experience)]
# Out:
# Empty DataFrame
# Columns: [n_id, name_node_a, n_type, n_category, n_gender, n_age, n_experience, n_idweirdness, name_node_aweirdness, n_typeweirdness, n_categoryweirdness, n_genderweirdness, n_ageweirdness, n_experienceweirdness]
# Index: []

# %%
relaciones.head()
# Out:
# Campo                                          id_node_a name_node_a  \
# 0      eeca1815ef2efc089f12bfe8c1c4c7f7-c81e728d9d4c2...       Team3
# 1      eeca1815ef2efc089f12bfe8c1c4c7f7-c81e728d9d4c2...       Team3
# 2      eeca1815ef2efc089f12bfe8c1c4c7f7-c81e728d9d4c2...       Team3
# 3      73cceb4a6d1f1fd7e91d38c2b906be15-c81e728d9d4c2...       Team2
# 4      73cceb4a6d1f1fd7e91d38c2b906be15-c81e728d9d4c2...       Team2
#
# Campo                                          id_node_b name_node_b  \
# 0      f496c7004f07dba853bf8fadc28c9650-c81e728d9d4c2...      Daniel
# 1      1ae7f988daa7541df8d9eba692e3949d-c81e728d9d4c2...     Marcela
# 2      a5b6fc8ad5a79c2b57af4137389a7b6b-c81e728d9d4c2...     Marcelo
# 3      e726642e86168eacfeee3fa8c4da012e-c81e728d9d4c2...    Leonardo
# 4      10c246e19e023f335e179b937c28a6da-c81e728d9d4c2...      Matias
#
# Campo                                    id_relationship  id_node_aweirdness  \
# 0      78031203cb9f8df3b96024f973e93dce-c81e728d9d4c2...                   0
# 1      920da6fdbb28002170bd11ac31f931fa-c81e728d9d4c2...                   0
# 2      d5f338d4f13a96698fda12514a76e4ad-c81e728d9d4c2...                   0
# 3      bad0c7e4278c68df0eeadaaa9499f260-c81e728d9d4c2...                   0
# 4      ff8fe587c76f4587b2fe3c6a4bd98d86-c81e728d9d4c2...                   0
#
# Campo  name_node_aweirdness  id_node_bweirdness  name_node_bweirdness  \
# 0                         0                   0                     0
# 1                         0                   0                     0
# 2                         0                   0                     0
# 3                         0                   0                     0
# 4                         0                   0                     0
#
# Campo  id_relationshipweirdness
# 0                             0
# 1                             0
# 2                             0
# 3                             0
# 4                             0

# %% [markdown]
# f.

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(nodos[nodos.n_type=='person'].n_age.dropna())
# Out:
# (array([3., 2., 1., 0., 1., 4., 0., 0., 1., 2.]),
#  array([23. , 25.2, 27.4, 29.6, 31.8, 34. , 36.2, 38.4, 40.6, 42.8, 45. ]),
#  <a list of 10 Patch objects>)

# %%
plt.boxplot(nodos[nodos.n_type=='person'].n_age.dropna(), whis=3)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x24b63b54388>,
#   <matplotlib.lines.Line2D at 0x24b63b4df88>],
#  'caps': [<matplotlib.lines.Line2D at 0x24b63b54e88>,
#   <matplotlib.lines.Line2D at 0x24b63b54c48>],
#  'boxes': [<matplotlib.lines.Line2D at 0x24b63b4db88>],
#  'medians': [<matplotlib.lines.Line2D at 0x24b63b54fc8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x24b63b58ec8>],
#  'means': []}

# %%
outliers = nodos[nodos.n_age > (nodos.n_age.mean() + 3 * nodos.n_age.std())]
display(outliers)
# Out:
# Empty DataFrame
# Columns: [n_id, name_node_a, n_type, n_category, n_gender, n_age, n_experience, n_idweirdness, name_node_aweirdness, n_typeweirdness, n_categoryweirdness, n_genderweirdness, n_ageweirdness, n_experienceweirdness]
# Index: []

# %%
plt.hist(nodos[nodos.n_type=='person'].n_experience.dropna())
# Out:
# (array([6., 2., 2., 1., 0., 0., 1., 1., 0., 1.]),
#  array([ 2. ,  3.4,  4.8,  6.2,  7.6,  9. , 10.4, 11.8, 13.2, 14.6, 16. ]),
#  <a list of 10 Patch objects>)

# %%
plt.boxplot(nodos[nodos.n_type=='person'].n_experience.dropna(), whis=3)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x24b63c31f08>,
#   <matplotlib.lines.Line2D at 0x24b63c31cc8>],
#  'caps': [<matplotlib.lines.Line2D at 0x24b63c37c08>,
#   <matplotlib.lines.Line2D at 0x24b63c379c8>],
#  'boxes': [<matplotlib.lines.Line2D at 0x24b63c31888>],
#  'medians': [<matplotlib.lines.Line2D at 0x24b63c37f48>],
#  'fliers': [<matplotlib.lines.Line2D at 0x24b63c3dc48>],
#  'means': []}

# %%
outliers = nodos[nodos.n_experience > (nodos.n_experience.mean() + 3 * nodos.n_experience.std())]
display(outliers)
# Out:
# Empty DataFrame
# Columns: [n_id, name_node_a, n_type, n_category, n_gender, n_age, n_experience, n_idweirdness, name_node_aweirdness, n_typeweirdness, n_categoryweirdness, n_genderweirdness, n_ageweirdness, n_experienceweirdness]
# Index: []

# %%
nodos[nodos.n_experience == 16]
# Out:
# Campo                                               n_id name_node_a  n_type  \
# 4      e726642e86168eacfeee3fa8c4da012e-c81e728d9d4c2...    Leonardo  person
#
# Campo n_category n_gender  n_age  n_experience  n_idweirdness  \
# 4         senior     male   45.0          16.0              0
#
# Campo  name_node_aweirdness  n_typeweirdness  n_categoryweirdness  \
# 4                         0                0                    0
#
# Campo  n_genderweirdness  n_ageweirdness  n_experienceweirdness
# 4                      0               0                      0

# %% [markdown]
# Outliers: todos los valores están dentro de 3 desviaciones estándares. Hay una sola persona que cae fuera de 2 DS, con 16 años de experiencia, pero hemos decidido mantener el dato dado el tamaño de la muestra analizada. Utilizamos el criterio de 3 DS a pesar de que los datos muestrales no se distribuyan normal, por convención y falta de un mejor criterio.

# %% [markdown]
# g.

# %%
nodos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   n_id                   92 non-null     object
#  1   name_node_a            92 non-null     object
#  2   n_type                 91 non-null     object
#  3   n_category             14 non-null     object
#  4   n_gender               14 non-null     object
#  5   n_age                  22 non-null     float64
#  6   n_experience           14 non-null     float64
#  7   n_idweirdness          92 non-null     int64
#  8   name_node_aweirdness   92 non-null     int64
#  9   n_typeweirdness        92 non-null     int64
#  10  n_categoryweirdness    92 non-null     int64
#  11  n_genderweirdness      92 non-null     int64
#  12  n_ageweirdness         92 non-null     int64
#  13  n_experienceweirdness  92 non-null     int64
# dtypes: float64(2), int64(7), object(5)
# memory usage: 10.2+ KB

# %%
datos_faltantes_nodos_cuenta = nodos.isnull().sum()
datos_faltantes_nodos_cuenta
# Out:
# Campo
# n_id                      0
# name_node_a               0
# n_type                    1
# n_category               78
# n_gender                 78
# n_age                    70
# n_experience             78
# n_idweirdness             0
# name_node_aweirdness      0
# n_typeweirdness           0
# n_categoryweirdness       0
# n_genderweirdness         0
# n_ageweirdness            0
# n_experienceweirdness     0
# dtype: int64

# %%
nodos[(nodos.n_type == "person") & (nodos.n_category == "NaN")]
# Out:
# Empty DataFrame
# Columns: [n_id, name_node_a, n_type, n_category, n_gender, n_age, n_experience, n_idweirdness, name_node_aweirdness, n_typeweirdness, n_categoryweirdness, n_genderweirdness, n_ageweirdness, n_experienceweirdness]
# Index: []

# %%
nodos[(nodos.n_type == "person") & (nodos.n_gender == "NaN")]
# Out:
# Empty DataFrame
# Columns: [n_id, name_node_a, n_type, n_category, n_gender, n_age, n_experience, n_idweirdness, name_node_aweirdness, n_typeweirdness, n_categoryweirdness, n_genderweirdness, n_ageweirdness, n_experienceweirdness]
# Index: []

# %%
nodos[(nodos.n_type == "person") & (nodos.n_age == "NaN")]
# Out:
# Empty DataFrame
# Columns: [n_id, name_node_a, n_type, n_category, n_gender, n_age, n_experience, n_idweirdness, name_node_aweirdness, n_typeweirdness, n_categoryweirdness, n_genderweirdness, n_ageweirdness, n_experienceweirdness]
# Index: []

# %%
nodos[(nodos.n_type == "person") & (nodos.n_experience == "NaN")]
# Out:
# Empty DataFrame
# Columns: [n_id, name_node_a, n_type, n_category, n_gender, n_age, n_experience, n_idweirdness, name_node_aweirdness, n_typeweirdness, n_categoryweirdness, n_genderweirdness, n_ageweirdness, n_experienceweirdness]
# Index: []

# %% [markdown]
# Los campos nulos corresponden a personas.

# %% [markdown]
# Se destacan dos problemas: un n_type nulo, y una diferencia de 8 datos entre edad y experiencia.

# %%
nodos[nodos.n_type.isnull()]
# Out:
# Campo                                               n_id name_node_a n_type  \
# 10     dd05195a0be8a3102470e9d6955e49be-c81e728d9d4c2...    Perfiles    NaN
#
# Campo n_category n_gender  n_age  n_experience  n_idweirdness  \
# 10           NaN      NaN    NaN           NaN              0
#
# Campo  name_node_aweirdness  n_typeweirdness  n_categoryweirdness  \
# 10                        0                0                    0
#
# Campo  n_genderweirdness  n_ageweirdness  n_experienceweirdness
# 10                     0               0                      0

# %%
nodos[nodos['name_node_a'] == 'Perfiles'].dropna(inplace=True)

# %%
nodos = nodos[nodos['name_node_a'] != 'Perfiles']
nodos
# Out:
# Campo                                               n_id  name_node_a  \
# 0      eeca1815ef2efc089f12bfe8c1c4c7f7-c81e728d9d4c2...        Team3
# 1      73cceb4a6d1f1fd7e91d38c2b906be15-c81e728d9d4c2...        Team2
# 2      1ae7f988daa7541df8d9eba692e3949d-c81e728d9d4c2...      Marcela
# 3      f496c7004f07dba853bf8fadc28c9650-c81e728d9d4c2...       Daniel
# 4      e726642e86168eacfeee3fa8c4da012e-c81e728d9d4c2...     Leonardo
# ..                                                   ...          ...
# 87     ffeffd6344800bfc7214b6d7ef83ea10-a87ff679a2f3e...       talend
# 88     362da8a51e150638e6981d0771534c8e-a87ff679a2f3e...      pentaho
# 89     263db3933c2cb8e9b139373fdd57defb-a87ff679a2f3e...  Integracion
# 90     de1284aa9ed99ad37c8259c2028b161c-a87ff679a2f3e...          ODI
# 91     bb906c05289c29654b54a94ced2e697c-a87ff679a2f3e...    Lenguajes
#
# Campo        n_type n_category n_gender  n_age  n_experience  n_idweirdness  \
# 0              team        NaN      NaN    0.0           NaN              0
# 1              team        NaN      NaN    0.0           NaN              0
# 2            person     junior   female   23.0           3.0              0
# 3            person     senior     male   44.0          11.0              0
# 4            person     senior     male   45.0          16.0              0
# ..              ...        ...      ...    ...           ...            ...
# 87     technologies        NaN      NaN    NaN           NaN              0
# 88     technologies        NaN      NaN    NaN           NaN              0
# 89     technologies        NaN      NaN    NaN           NaN              0
# 90     technologies        NaN      NaN    NaN           NaN              0
# 91     technologies        NaN      NaN    NaN           NaN              0
#
# Campo  name_node_aweirdness  n_typeweirdness  n_categoryweirdness  \
# 0                         0                0                    0
# 1                         0                0                    0
# 2                         0                0                    0
# 3                         0                0                    0
# 4                         0                0                    0
# ..                      ...              ...                  ...
# 87                        0                0                    0
# 88                        0                0                    0
# 89                        0                0                    0
# 90                        0                0                    0
# 91                        0                0                    0
#
# Campo  n_genderweirdness  n_ageweirdness  n_experienceweirdness
# 0                      0               0                      0
# 1                      0               0                      0
# 2                      0               0                      0
# 3                      0               0                      0
# 4                      0               0                      0
# ..                   ...             ...                    ...
# 87                     0               0                      0
# 88                     0               0                      0
# 89                     0               0                      0
# 90                     0               0                      0
# 91                     0               0                      0
#
# [91 rows x 14 columns]

# %% [markdown]
# Perfiles corresponde a una categoría no expecificada, sobre el cual se construirá en el futuro.

# %%
nodos[(nodos.n_experience == "NaN") & (nodos.n_age != "NaN")]
# Out:
# Empty DataFrame
# Columns: [n_id, name_node_a, n_type, n_category, n_gender, n_age, n_experience, n_idweirdness, name_node_aweirdness, n_typeweirdness, n_categoryweirdness, n_genderweirdness, n_ageweirdness, n_experienceweirdness]
# Index: []

# %%
nodos[(nodos.n_age == "0")]
# Out:
# Empty DataFrame
# Columns: [n_id, name_node_a, n_type, n_category, n_gender, n_age, n_experience, n_idweirdness, name_node_aweirdness, n_typeweirdness, n_categoryweirdness, n_genderweirdness, n_ageweirdness, n_experienceweirdness]
# Index: []

# %%
nodos[nodos.n_category.isnull()].head()
# Out:
# Campo                                               n_id  name_node_a  \
# 0      eeca1815ef2efc089f12bfe8c1c4c7f7-c81e728d9d4c2...        Team3
# 1      73cceb4a6d1f1fd7e91d38c2b906be15-c81e728d9d4c2...        Team2
# 11     ff64319904f4832ee19df96250276033-c81e728d9d4c2...      Inst DB
# 12     17fc99d3f691680db18b948f4b9a4547-a87ff679a2f3e...   AWS Lambda
# 13     31985bb925fa449ee8d01350cb2f008d-a87ff679a2f3e...  AWS Kinesis
#
# Campo        n_type n_category n_gender  n_age  n_experience  n_idweirdness  \
# 0              team        NaN      NaN    0.0           NaN              0
# 1              team        NaN      NaN    0.0           NaN              0
# 11     technologies        NaN      NaN    NaN           NaN              0
# 12     technologies        NaN      NaN    NaN           NaN              0
# 13     technologies        NaN      NaN    NaN           NaN              0
#
# Campo  name_node_aweirdness  n_typeweirdness  n_categoryweirdness  \
# 0                         0                0                    0
# 1                         0                0                    0
# 11                        0                0                    0
# 12                        0                0                    0
# 13                        0                0                    0
#
# Campo  n_genderweirdness  n_ageweirdness  n_experienceweirdness
# 0                      0               0                      0
# 1                      0               0                      0
# 11                     0               0                      0
# 12                     0               0                      0
# 13                     0               0                      0

# %%
nodos[nodos.n_age == 0]
# Out:
# Campo                                               n_id       name_node_a  \
# 0      eeca1815ef2efc089f12bfe8c1c4c7f7-c81e728d9d4c2...             Team3
# 1      73cceb4a6d1f1fd7e91d38c2b906be15-c81e728d9d4c2...             Team2
# 24     4cd45b1d7210ec9b517bd44c201454ba-a87ff679a2f3e...             Team1
# 71     6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e...    Data Scientist
# 72     720d1c3fee7aef666abe0c50a9a7cde1-a87ff679a2f3e...               DBA
# 73     ac894b03f495d68a60f2d786e79aa1e3-a87ff679a2f3e...    Data Architect
# 74     7d49add0d0c4fa941e927e85ad5226f2-a87ff679a2f3e...         Developer
# 75     4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e...  Technical Leader
#
# Campo n_type n_category n_gender  n_age  n_experience  n_idweirdness  \
# 0       team        NaN      NaN    0.0           NaN              0
# 1       team        NaN      NaN    0.0           NaN              0
# 24      team        NaN      NaN    0.0           NaN              0
# 71     skill        NaN      NaN    0.0           NaN              0
# 72     skill        NaN      NaN    0.0           NaN              0
# 73     skill        NaN      NaN    0.0           NaN              0
# 74     skill        NaN      NaN    0.0           NaN              0
# 75     skill        NaN      NaN    0.0           NaN              0
#
# Campo  name_node_aweirdness  n_typeweirdness  n_categoryweirdness  \
# 0                         0                0                    0
# 1                         0                0                    0
# 24                        0                0                    0
# 71                        0                0                    0
# 72                        0                0                    0
# 73                        0                0                    0
# 74                        0                0                    0
# 75                        0                0                    0
#
# Campo  n_genderweirdness  n_ageweirdness  n_experienceweirdness
# 0                      0               0                      0
# 1                      0               0                      0
# 24                     0               0                      0
# 71                     0               0                      0
# 72                     0               0                      0
# 73                     0               0                      0
# 74                     0               0                      0
# 75                     0               0                      0

# %% [markdown]
# La diferencia está en que hay 3 "Teams" y 5 "Skills" que tienen asignada edad cero. Se la reemplazará por "NaN".

# %%
nodos[nodos.n_age == 0].replace(0, 'NaN')
# Out:
# Campo                                               n_id       name_node_a  \
# 0      eeca1815ef2efc089f12bfe8c1c4c7f7-c81e728d9d4c2...             Team3
# 1      73cceb4a6d1f1fd7e91d38c2b906be15-c81e728d9d4c2...             Team2
# 24     4cd45b1d7210ec9b517bd44c201454ba-a87ff679a2f3e...             Team1
# 71     6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e...    Data Scientist
# 72     720d1c3fee7aef666abe0c50a9a7cde1-a87ff679a2f3e...               DBA
# 73     ac894b03f495d68a60f2d786e79aa1e3-a87ff679a2f3e...    Data Architect
# 74     7d49add0d0c4fa941e927e85ad5226f2-a87ff679a2f3e...         Developer
# 75     4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e...  Technical Leader
#
# Campo n_type n_category n_gender n_age  n_experience n_idweirdness  \
# 0       team        NaN      NaN   NaN           NaN           NaN
# 1       team        NaN      NaN   NaN           NaN           NaN
# 24      team        NaN      NaN   NaN           NaN           NaN
# 71     skill        NaN      NaN   NaN           NaN           NaN
# 72     skill        NaN      NaN   NaN           NaN           NaN
# 73     skill        NaN      NaN   NaN           NaN           NaN
# 74     skill        NaN      NaN   NaN           NaN           NaN
# 75     skill        NaN      NaN   NaN           NaN           NaN
#
# Campo name_node_aweirdness n_typeweirdness n_categoryweirdness  \
# 0                      NaN             NaN                 NaN
# 1                      NaN             NaN                 NaN
# 24                     NaN             NaN                 NaN
# 71                     NaN             NaN                 NaN
# 72                     NaN             NaN                 NaN
# 73                     NaN             NaN                 NaN
# 74                     NaN             NaN                 NaN
# 75                     NaN             NaN                 NaN
#
# Campo n_genderweirdness n_ageweirdness n_experienceweirdness
# 0                   NaN            NaN                   NaN
# 1                   NaN            NaN                   NaN
# 24                  NaN            NaN                   NaN
# 71                  NaN            NaN                   NaN
# 72                  NaN            NaN                   NaN
# 73                  NaN            NaN                   NaN
# 74                  NaN            NaN                   NaN
# 75                  NaN            NaN                   NaN

# %% [markdown]
# h.

# %%
#nodos[nodos['name_node_a']== 'busqueda_skill']

# %% [markdown]
# from sklearn import preprocessing

# %% [markdown]
# nodos.describe(include=['O'])

# %% [markdown]
# nodos.n_type.unique()

# %% [markdown]
# nodos.n_gender

# %% [markdown]
# relaciones.describe(include=['O'])

# %% [markdown]
# le = preprocessing.LabelEncoder()
# le.fit(nodos['n_type'])
# dict(zip(le.classes_, le.transform(le.classes_)))

# %% [markdown]
# nodos['n_type'] = le.transform(nodos['n_type'])

# %% [markdown]
# nodos['n_gender'].fillna('no_gender', inplace=True)
# le = preprocessing.LabelEncoder()
# le.fit(nodos['n_gender'])
# dict(zip(le.classes_, le.transform(le.classes_)))

# %% [markdown]
# nodos['n_gender'] = le.transform(nodos['n_gender'])

# %% [markdown]
# nodos['n_category'].fillna('no_category', inplace=True)
# le = preprocessing.LabelEncoder()
# le.fit(nodos['n_category'])
# dict(zip(le.classes_, le.transform(le.classes_)))

# %% [markdown]
# nodos['n_category'] = le.transform(nodos['n_category'])

# %% [markdown]
# #nodos['name_node_a'].fillna('no_name', inplace=True)
# le = preprocessing.LabelEncoder()
# le.fit(nodos['name_node_a'])
# dict(zip(le.classes_, le.transform(le.classes_)))

# %% [markdown]
# nodos['name_node_a'] = le.transform(nodos['name_node_a'])

# %% [markdown]
# nodos = nodos.iloc[:,:7]
# nodos

# %% [markdown]
# nodos.n_experience.fillna(0, inplace=True)
# nodos.n_age.fillna(0, inplace=True)

# %% [markdown]
# le = preprocessing.LabelEncoder()
# le.fit(relaciones['name_node_a'])
# dict(zip(le.classes_, le.transform(le.classes_)))

# %% [markdown]
# relaciones['name_node_a'] = le.transform(relaciones['name_node_a'])

# %% [markdown]
# le = preprocessing.LabelEncoder()
# le.fit(relaciones['name_node_b'])
# dict(zip(le.classes_, le.transform(le.classes_)))

# %% [markdown]
# relaciones['name_node_b'] = le.transform(relaciones['name_node_b'])

# %% [markdown]
# relaciones = relaciones.iloc[:,:5]

# %% [markdown]
# relaciones

# %% [markdown]
# ## PREPARAMOS EL DATA SET 1

# %% [markdown]
# DATASET1- Preparar un dataset para usar modelos supervisados. Éste debe incluir las personas, los conocimientos, los perfiles (skills) opcional (los teams), que son las que se van a usar para en armar una regresión lineal sobre las personas con los años de experiencias vs el ranking que posee de sus conocimientos.\

# %% [markdown]
# #Seleccion de personas
# personas = nodos[nodos["n_type"] == 1]
#
# #Merge en un solo df
# df_1 = personas.merge(relaciones)
# display(df_1.head())
# #display(personas)

# %%
df_1 = nodos.merge(relaciones, left_on='n_id', right_on='id_node_a')

# %%
df_1 = df_1[df_1['n_type']=='person'][['name_node_a_x', 'name_node_b', 'n_category', 'n_age', 'n_experience']]
df_1
# Out:
# Campo name_node_a_x     name_node_b n_category  n_age  n_experience
# 8           Marcela       Developer     junior   23.0           3.0
# 9           Marcela         windows     junior   23.0           3.0
# 10          Marcela           Linux     junior   23.0           3.0
# 11          Marcela           MySQL     junior   23.0           3.0
# 12          Marcela          phyton     junior   23.0           3.0
# ..              ...             ...        ...    ...           ...
# 112          Martin  Data Scientist     senior   34.0           5.0
# 113          Martin         Vertica     senior   34.0           5.0
# 114          Martin      SQL Server     senior   34.0           5.0
# 115          Martin          phyton     senior   34.0           5.0
# 116          Martin             ODI     senior   34.0           5.0
#
# [106 rows x 5 columns]

# %% [markdown]
# DATASET2- Preparar el dataset para el práctico de aprendizaje no supervisado. Éste está orientado a descubrir dentificar los perfiles que puede poseer cada persona, en base a ciertas personas ya clasificadas, por lo que en éste caso debe filtrar éste subconjunto de perfiles (Skills).\

# %% [markdown]
# df_2 = df_1[df_1['name_node_b'].isin([11, 12, 13])]
# df_2
# data_scientist = df_2
# data_scientist

# %% [markdown]
# df_3 = df_1[df_1['name_node_a_x'].isin([29, 55])]
# df_3 = df_3[df_3['name_node_b']!=13]
# data_scientist_skills = df_3
# data_scientist_skills

# %% [markdown]
# DF2 = nodos[nodos['n_type'].isin([1, 2, 4, 4])].merge(relaciones, left_on='n_id', right_on='id_node_a')
# DF2 = DF2[['name_node_a_x','n_category', 'name_node_a_y', 'name_node_b']]
# DF2

# %%
nodos = nodos_
relaciones = relaciones_

# %% [markdown]
# DF2 = nodos[nodos['n_type'].isin(['person'])].merge(relaciones, left_on='n_id', right_on='id_node_a')
# DF2 =  DF2[['name_node_a_x','n_category', 'name_node_a_y', 'name_node_b']]
# DF2

# %% [markdown]
# skill, nombre, tech

# %%
df2 = nodos[nodos.n_type=='skill'].merge(relaciones, left_on='n_id', right_on='id_node_b')
df2 = df2[['name_node_a_x', 'n_type', 'name_node_a_y', 'id_node_a', 'id_node_b']]
df2
# Out:
# Campo     name_node_a_x n_type name_node_a_y  \
# 0        Data Scientist  skill      Perfiles
# 1        Data Scientist  skill      Fernando
# 2        Data Scientist  skill        Martin
# 3                   DBA  skill       Marcelo
# 4                   DBA  skill      Perfiles
# 5                   DBA  skill       Jonatan
# 6                   DBA  skill         Lucas
# 7                   DBA  skill        Gastón
# 8        Data Architect  skill      Perfiles
# 9             Developer  skill       Marcela
# 10            Developer  skill      Leonardo
# 11            Developer  skill        Matias
# 12            Developer  skill        Miguel
# 13            Developer  skill       Luciana
# 14            Developer  skill      Perfiles
# 15            Developer  skill        Andrea
# 16     Technical Leader  skill        Daniel
# 17     Technical Leader  skill        Lionel
# 18     Technical Leader  skill      Perfiles
# 19        Data Engineer  skill      Perfiles
#
# Campo                                          id_node_a  \
# 0      dd05195a0be8a3102470e9d6955e49be-c81e728d9d4c2...
# 1      51280652ee54bf9e25636110b859faf5-a87ff679a2f3e...
# 2      8ebb5bf7f39a9ec7304a17cdf5063df9-a87ff679a2f3e...
# 3      a5b6fc8ad5a79c2b57af4137389a7b6b-c81e728d9d4c2...
# 4      dd05195a0be8a3102470e9d6955e49be-c81e728d9d4c2...
# 5      79b60482d282d7fe48287ef484be2d31-a87ff679a2f3e...
# 6      6bb28c0af81044a5f2bf023eb7f253e2-a87ff679a2f3e...
# 7      f6b8790fd8dcb51f4ccec2e19f6db824-a87ff679a2f3e...
# 8      dd05195a0be8a3102470e9d6955e49be-c81e728d9d4c2...
# 9      1ae7f988daa7541df8d9eba692e3949d-c81e728d9d4c2...
# 10     e726642e86168eacfeee3fa8c4da012e-c81e728d9d4c2...
# 11     10c246e19e023f335e179b937c28a6da-c81e728d9d4c2...
# 12     f9fdac801645d8b673ce785f01658a1e-c81e728d9d4c2...
# 13     822736b3fe21296f7d5c35a5e13d3ca3-c81e728d9d4c2...
# 14     dd05195a0be8a3102470e9d6955e49be-c81e728d9d4c2...
# 15     533348a1f755b9512eb8b91aa07a300a-a87ff679a2f3e...
# 16     f496c7004f07dba853bf8fadc28c9650-c81e728d9d4c2...
# 17     bcb93d9680b08656367b3682a9b4c127-c81e728d9d4c2...
# 18     dd05195a0be8a3102470e9d6955e49be-c81e728d9d4c2...
# 19     dd05195a0be8a3102470e9d6955e49be-c81e728d9d4c2...
#
# Campo                                          id_node_b
# 0      6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e...
# 1      6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e...
# 2      6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e...
# 3      720d1c3fee7aef666abe0c50a9a7cde1-a87ff679a2f3e...
# 4      720d1c3fee7aef666abe0c50a9a7cde1-a87ff679a2f3e...
# 5      720d1c3fee7aef666abe0c50a9a7cde1-a87ff679a2f3e...
# 6      720d1c3fee7aef666abe0c50a9a7cde1-a87ff679a2f3e...
# 7      720d1c3fee7aef666abe0c50a9a7cde1-a87ff679a2f3e...
# 8      ac894b03f495d68a60f2d786e79aa1e3-a87ff679a2f3e...
# 9      7d49add0d0c4fa941e927e85ad5226f2-a87ff679a2f3e...
# 10     7d49add0d0c4fa941e927e85ad5226f2-a87ff679a2f3e...
# 11     7d49add0d0c4fa941e927e85ad5226f2-a87ff679a2f3e...
# 12     7d49add0d0c4fa941e927e85ad5226f2-a87ff679a2f3e...
# 13     7d49add0d0c4fa941e927e85ad5226f2-a87ff679a2f3e...
# 14     7d49add0d0c4fa941e927e85ad5226f2-a87ff679a2f3e...
# 15     7d49add0d0c4fa941e927e85ad5226f2-a87ff679a2f3e...
# 16     4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e...
# 17     4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e...
# 18     4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e...
# 19     a8cea7ec2709db07e628b80e2dafa2b6-a87ff679a2f3e...

# %%
t = nodos[nodos.n_type=='technologies'].merge(relaciones)
t = t[['n_id', 'name_node_a', 'id_node_b']]
t
# Out:
# Campo                                               n_id  \
# 0      c75df195acce9063a96459de85bc72b9-a87ff679a2f3e...
# 1      c75df195acce9063a96459de85bc72b9-a87ff679a2f3e...
# 2      35c4798d0240368c638e55bae0d57ffa-a87ff679a2f3e...
# 3      4631193902bfaa235973c349bce7a3a7-a87ff679a2f3e...
# 4      dbc99b3e3534c783415b59b687bd3b49-a87ff679a2f3e...
# ..                                                   ...
# 63     bb906c05289c29654b54a94ced2e697c-a87ff679a2f3e...
# 64     bb906c05289c29654b54a94ced2e697c-a87ff679a2f3e...
# 65     bb906c05289c29654b54a94ced2e697c-a87ff679a2f3e...
# 66     bb906c05289c29654b54a94ced2e697c-a87ff679a2f3e...
# 67     bb906c05289c29654b54a94ced2e697c-a87ff679a2f3e...
#
# Campo                                  name_node_a  \
# 0      Monta un Cluster Hadoop Big Data desde Cero
# 1      Monta un Cluster Hadoop Big Data desde Cero
# 2                                            Linux
# 3                                       Kubernetes
# 4                                            Redis
# ..                                             ...
# 63                                       Lenguajes
# 64                                       Lenguajes
# 65                                       Lenguajes
# 66                                       Lenguajes
# 67                                       Lenguajes
#
# Campo                                          id_node_b
# 0      7e978e6cfaa3e6de95722312e007357f-a87ff679a2f3e...
# 1      f441e44866d2cf1fa1edd368e0723cc8-a87ff679a2f3e...
# 2      deafefd874acdccf7a2c9c1d235ecf62-a87ff679a2f3e...
# 3      52dcc954f0e2235ecd4675e7966ec6ef-a87ff679a2f3e...
# 4      033b8b21e9a6bb06969eaf9e9f5b3abd-a87ff679a2f3e...
# ..                                                   ...
# 63     202a4729f08cfad5658fb7a6fb4ab47a-a87ff679a2f3e...
# 64     1e242f2a98674de62d26b486d59b4c70-a87ff679a2f3e...
# 65     7f85fb3ca43d29a9100c4519e12f2fcd-a87ff679a2f3e...
# 66     bbbe1fbd5a476cc46c35ea4b051c1a36-a87ff679a2f3e...
# 67     a1e01b9df0dab2bfd6d9b32e10e397c8-a87ff679a2f3e...
#
# [68 rows x 3 columns]

# %%
df2.merge(t, left_on='id_node_b' , right_on='id_node_b')
df2
# Out:
# Campo     name_node_a_x n_type name_node_a_y  \
# 0        Data Scientist  skill      Perfiles
# 1        Data Scientist  skill      Fernando
# 2        Data Scientist  skill        Martin
# 3                   DBA  skill       Marcelo
# 4                   DBA  skill      Perfiles
# 5                   DBA  skill       Jonatan
# 6                   DBA  skill         Lucas
# 7                   DBA  skill        Gastón
# 8        Data Architect  skill      Perfiles
# 9             Developer  skill       Marcela
# 10            Developer  skill      Leonardo
# 11            Developer  skill        Matias
# 12            Developer  skill        Miguel
# 13            Developer  skill       Luciana
# 14            Developer  skill      Perfiles
# 15            Developer  skill        Andrea
# 16     Technical Leader  skill        Daniel
# 17     Technical Leader  skill        Lionel
# 18     Technical Leader  skill      Perfiles
# 19        Data Engineer  skill      Perfiles
#
# Campo                                          id_node_a  \
# 0      dd05195a0be8a3102470e9d6955e49be-c81e728d9d4c2...
# 1      51280652ee54bf9e25636110b859faf5-a87ff679a2f3e...
# 2      8ebb5bf7f39a9ec7304a17cdf5063df9-a87ff679a2f3e...
# 3      a5b6fc8ad5a79c2b57af4137389a7b6b-c81e728d9d4c2...
# 4      dd05195a0be8a3102470e9d6955e49be-c81e728d9d4c2...
# 5      79b60482d282d7fe48287ef484be2d31-a87ff679a2f3e...
# 6      6bb28c0af81044a5f2bf023eb7f253e2-a87ff679a2f3e...
# 7      f6b8790fd8dcb51f4ccec2e19f6db824-a87ff679a2f3e...
# 8      dd05195a0be8a3102470e9d6955e49be-c81e728d9d4c2...
# 9      1ae7f988daa7541df8d9eba692e3949d-c81e728d9d4c2...
# 10     e726642e86168eacfeee3fa8c4da012e-c81e728d9d4c2...
# 11     10c246e19e023f335e179b937c28a6da-c81e728d9d4c2...
# 12     f9fdac801645d8b673ce785f01658a1e-c81e728d9d4c2...
# 13     822736b3fe21296f7d5c35a5e13d3ca3-c81e728d9d4c2...
# 14     dd05195a0be8a3102470e9d6955e49be-c81e728d9d4c2...
# 15     533348a1f755b9512eb8b91aa07a300a-a87ff679a2f3e...
# 16     f496c7004f07dba853bf8fadc28c9650-c81e728d9d4c2...
# 17     bcb93d9680b08656367b3682a9b4c127-c81e728d9d4c2...
# 18     dd05195a0be8a3102470e9d6955e49be-c81e728d9d4c2...
# 19     dd05195a0be8a3102470e9d6955e49be-c81e728d9d4c2...
#
# Campo                                          id_node_b
# 0      6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e...
# 1      6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e...
# 2      6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e...
# 3      720d1c3fee7aef666abe0c50a9a7cde1-a87ff679a2f3e...
# 4      720d1c3fee7aef666abe0c50a9a7cde1-a87ff679a2f3e...
# 5      720d1c3fee7aef666abe0c50a9a7cde1-a87ff679a2f3e...
# 6      720d1c3fee7aef666abe0c50a9a7cde1-a87ff679a2f3e...
# 7      720d1c3fee7aef666abe0c50a9a7cde1-a87ff679a2f3e...
# 8      ac894b03f495d68a60f2d786e79aa1e3-a87ff679a2f3e...
# 9      7d49add0d0c4fa941e927e85ad5226f2-a87ff679a2f3e...
# 10     7d49add0d0c4fa941e927e85ad5226f2-a87ff679a2f3e...
# 11     7d49add0d0c4fa941e927e85ad5226f2-a87ff679a2f3e...
# 12     7d49add0d0c4fa941e927e85ad5226f2-a87ff679a2f3e...
# 13     7d49add0d0c4fa941e927e85ad5226f2-a87ff679a2f3e...
# 14     7d49add0d0c4fa941e927e85ad5226f2-a87ff679a2f3e...
# 15     7d49add0d0c4fa941e927e85ad5226f2-a87ff679a2f3e...
# 16     4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e...
# 17     4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e...
# 18     4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e...
# 19     a8cea7ec2709db07e628b80e2dafa2b6-a87ff679a2f3e...

# %%
a = nodos[nodos['n_type']=='technologies']
techs = a['name_node_a'].unique()
techs
# Out:
# array(['Inst DB', 'AWS Lambda', 'AWS Kinesis', 'DynamoDB',
#        'Monta un Cluster Hadoop Big Data desde Cero', 'cursos', 'Linux',
#        'EC2', 'Kubernetes', 'Redis', 'HBase', 'neo4j', 'Graph db',
#        'Oracle Cloud', 'Huawei', 'Spark', 'Vertica', 'Cassandra', 'CQL',
#        'MongoDB', 'Athena', 'RDS', 'Glue', 'IAM', 'S3', 'EMR',
#        'Golden Gate', 'Cask', 'Azkaban', 'Luigi', 'Airflow', 'MS SSIS',
#        'SQL', 'unix', 'windows', 'SO', 'Contenedores', 'In-memory',
#        'NoSQL', 'Data warehouse', 'MariaDB', 'PDI', 'SQL Server', 'R',
#        'scala', 'java', 'phyton', 'Google cloud', 'Azure', 'AWS',
#        'Cloud Computing', 'Hadoop', 'Procesamiento', 'Docker',
#        'Bases de Datos', 'Oracle', 'PostgreSQL', 'Relacionales', 'MySQL',
#        'Documentales', 'Columnares', 'ETL', 'talend', 'pentaho',
#        'Integracion', 'ODI', 'Lenguajes'], dtype=object)

# %%
a = df2.merge(df_1, left_on='name_node_a_y', right_on='name_node_a_x')
a
# Out:
# Campo   name_node_a_x_x n_type name_node_a_y  \
# 0        Data Scientist  skill      Fernando
# 1        Data Scientist  skill      Fernando
# 2        Data Scientist  skill      Fernando
# 3        Data Scientist  skill      Fernando
# 4        Data Scientist  skill      Fernando
# ..                  ...    ...           ...
# 101    Technical Leader  skill        Lionel
# 102    Technical Leader  skill        Lionel
# 103    Technical Leader  skill        Lionel
# 104    Technical Leader  skill        Lionel
# 105    Technical Leader  skill        Lionel
#
# Campo                                          id_node_a  \
# 0      51280652ee54bf9e25636110b859faf5-a87ff679a2f3e...
# 1      51280652ee54bf9e25636110b859faf5-a87ff679a2f3e...
# 2      51280652ee54bf9e25636110b859faf5-a87ff679a2f3e...
# 3      51280652ee54bf9e25636110b859faf5-a87ff679a2f3e...
# 4      51280652ee54bf9e25636110b859faf5-a87ff679a2f3e...
# ..                                                   ...
# 101    bcb93d9680b08656367b3682a9b4c127-c81e728d9d4c2...
# 102    bcb93d9680b08656367b3682a9b4c127-c81e728d9d4c2...
# 103    bcb93d9680b08656367b3682a9b4c127-c81e728d9d4c2...
# 104    bcb93d9680b08656367b3682a9b4c127-c81e728d9d4c2...
# 105    bcb93d9680b08656367b3682a9b4c127-c81e728d9d4c2...
#
# Campo                                          id_node_b name_node_a_x_y  \
# 0      6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e...        Fernando
# 1      6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e...        Fernando
# 2      6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e...        Fernando
# 3      6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e...        Fernando
# 4      6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e...        Fernando
# ..                                                   ...             ...
# 101    4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e...          Lionel
# 102    4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e...          Lionel
# 103    4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e...          Lionel
# 104    4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e...          Lionel
# 105    4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e...          Lionel
#
# Campo       name_node_b   n_category  n_age  n_experience
# 0        Data Scientist  semi-senior   28.0           4.0
# 1            AWS Lambda  semi-senior   28.0           4.0
# 2                phyton  semi-senior   28.0           4.0
# 3                Docker  semi-senior   28.0           4.0
# 4            Kubernetes  semi-senior   28.0           4.0
# ..                  ...          ...    ...           ...
# 101              Oracle  semi-senior   35.0           3.0
# 102        Google cloud  semi-senior   35.0           3.0
# 103              Docker  semi-senior   35.0           3.0
# 104               neo4j  semi-senior   35.0           3.0
# 105    Technical Leader  semi-senior   35.0           3.0
#
# [106 rows x 10 columns]

# %%
a = a[a['name_node_b'].isin(techs)]
a = a[['name_node_a_x_x','name_node_a_y', 'name_node_b', 'n_category', 'n_age', 'n_experience']]
df2 = a
df2
# Out:
# Campo   name_node_a_x_x name_node_a_y   name_node_b   n_category  n_age  \
# 1        Data Scientist      Fernando    AWS Lambda  semi-senior   28.0
# 2        Data Scientist      Fernando        phyton  semi-senior   28.0
# 3        Data Scientist      Fernando        Docker  semi-senior   28.0
# 4        Data Scientist      Fernando    Kubernetes  semi-senior   28.0
# 5        Data Scientist      Fernando         Linux  semi-senior   28.0
# ..                  ...           ...           ...          ...    ...
# 100    Technical Leader        Lionel          unix  semi-senior   35.0
# 101    Technical Leader        Lionel        Oracle  semi-senior   35.0
# 102    Technical Leader        Lionel  Google cloud  semi-senior   35.0
# 103    Technical Leader        Lionel        Docker  semi-senior   35.0
# 104    Technical Leader        Lionel         neo4j  semi-senior   35.0
#
# Campo  n_experience
# 1               4.0
# 2               4.0
# 3               4.0
# 4               4.0
# 5               4.0
# ..              ...
# 100             3.0
# 101             3.0
# 102             3.0
# 103             3.0
# 104             3.0
#
# [92 rows x 6 columns]

# %% [markdown]
# # Introducción al aprendizaje automático
#
# Lo primero que tenemos que entender es la jerarquía de los datos organizados en grafos de acuerdo a lo que necesitemos.
# En este caso:
# * Skills: nodo tipo skill
# * Personas: not tipo person
# * Tecnologias: nodo tipo knowledge
#
# Con estas vinculaciones trataremos de responder a la pregunta de la relación entre el conocimiento que poseen las personas y sus años de experiencia.

# %%
# Repetimos aquí la carga de los archivos
import pandas as pd
import numpy as np

#Lectura
# Vamos a abrir los archivos que poseen la información
# El primer archivo posee los nodos que contienen a las personas, skills, conocimientos, team  (como se explicó en el dataset)
# Aqui se encuentran todos los features de acuerdo al tipo de nodo
nodos = pd.read_csv(
    'https://raw.githubusercontent.com/fgpalacios/diplodatos2020/master/dataset/nodes.csv')

# El segundo archivo posee la relación que existen entre los nodos es decir un nodo persona tiene conocimientos vinculados que es lo que sabe
relaciones = pd.read_csv(
    'https://raw.githubusercontent.com/fgpalacios/diplodatos2020/master/dataset/relationships.csv')

#Display HTML
display(nodos.head())
display(relaciones.head())
# Out:
#                                                 n.id name_node_a  n.type  \
# 0  eeca1815ef2efc089f12bfe8c1c4c7f7-c81e728d9d4c2...       Team3    team
# 1  73cceb4a6d1f1fd7e91d38c2b906be15-c81e728d9d4c2...       Team2    team
# 2  1ae7f988daa7541df8d9eba692e3949d-c81e728d9d4c2...     Marcela  person
# 3  f496c7004f07dba853bf8fadc28c9650-c81e728d9d4c2...      Daniel  person
# 4  e726642e86168eacfeee3fa8c4da012e-c81e728d9d4c2...    Leonardo  person
#
#   n.category n.gender  n.age  n.experience
# 0        NaN      NaN    0.0           NaN
# 1        NaN      NaN    0.0           NaN
# 2     junior   female   23.0           3.0
# 3     senior     male   44.0          11.0
# 4     senior     male   45.0          16.0
#                                            id_node_a name_node_a  \
# 0  eeca1815ef2efc089f12bfe8c1c4c7f7-c81e728d9d4c2...       Team3
# 1  eeca1815ef2efc089f12bfe8c1c4c7f7-c81e728d9d4c2...       Team3
# 2  eeca1815ef2efc089f12bfe8c1c4c7f7-c81e728d9d4c2...       Team3
# 3  73cceb4a6d1f1fd7e91d38c2b906be15-c81e728d9d4c2...       Team2
# 4  73cceb4a6d1f1fd7e91d38c2b906be15-c81e728d9d4c2...       Team2
#
#                                            id_node_b name_node_b  \
# 0  f496c7004f07dba853bf8fadc28c9650-c81e728d9d4c2...      Daniel
# 1  1ae7f988daa7541df8d9eba692e3949d-c81e728d9d4c2...     Marcela
# 2  a5b6fc8ad5a79c2b57af4137389a7b6b-c81e728d9d4c2...     Marcelo
# 3  e726642e86168eacfeee3fa8c4da012e-c81e728d9d4c2...    Leonardo
# 4  10c246e19e023f335e179b937c28a6da-c81e728d9d4c2...      Matias
#
#                                      id_relationship
# 0  78031203cb9f8df3b96024f973e93dce-c81e728d9d4c2...
# 1  920da6fdbb28002170bd11ac31f931fa-c81e728d9d4c2...
# 2  d5f338d4f13a96698fda12514a76e4ad-c81e728d9d4c2...
# 3  bad0c7e4278c68df0eeadaaa9499f260-c81e728d9d4c2...
# 4  ff8fe587c76f4587b2fe3c6a4bd98d86-c81e728d9d4c2...

# %%
nodos['n.type'].unique()
# Out:
# array(['team', 'person', nan, 'technologies', 'skill', 'info'],
#       dtype=object)

# %% [markdown]
# Trabajemos solo con los nodos Skills, Person y Technologies

# %%
#Definimos un dataset de skill
skills = nodos[nodos["n.type"] == "skill"]

# Mejoramos los nombres de las columnas
skills.columns = skills.columns.str.replace('n.id', 'skill_id')
skills.columns = skills.columns.str.replace('name_node_a', 'skill_name')
skills.columns = skills.columns.str.replace('n.type', 'skill_type')
# Extractamos solo las columnas necesarias
skills = skills[['skill_id','skill_name','skill_type']]
skills
# Out:
#                                              skill_id        skill_name  \
# 71  6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e...    Data Scientist
# 72  720d1c3fee7aef666abe0c50a9a7cde1-a87ff679a2f3e...               DBA
# 73  ac894b03f495d68a60f2d786e79aa1e3-a87ff679a2f3e...    Data Architect
# 74  7d49add0d0c4fa941e927e85ad5226f2-a87ff679a2f3e...         Developer
# 75  4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e...  Technical Leader
# 76  a8cea7ec2709db07e628b80e2dafa2b6-a87ff679a2f3e...     Data Engineer
#
#    skill_type
# 71      skill
# 72      skill
# 73      skill
# 74      skill
# 75      skill
# 76      skill

# %%
#Definimos un dataset de personas
persons = nodos[nodos["n.type"] == "person"]
# persons['n.id']
#Mejoramos los nombres
persons.columns = persons.columns.str.replace('n.id', 'person_id')
persons.columns = persons.columns.str.replace('name_node_a', 'person_name')
persons.columns = persons.columns.str.replace('n.type', 'person_type')
persons.columns = persons.columns.str.replace('n.category', 'person_category')
persons.columns = persons.columns.str.replace('n.gender', 'person_gender')
persons.columns = persons.columns.str.replace('n.age', 'person_age')
persons.columns = persons.columns.str.replace('n.experience', 'person_experience')

persons.set_index('person_id')
persons
# Out:
#                                             person_id person_name person_type  \
# 2   1ae7f988daa7541df8d9eba692e3949d-c81e728d9d4c2...     Marcela      person
# 3   f496c7004f07dba853bf8fadc28c9650-c81e728d9d4c2...      Daniel      person
# 4   e726642e86168eacfeee3fa8c4da012e-c81e728d9d4c2...    Leonardo      person
# 5   10c246e19e023f335e179b937c28a6da-c81e728d9d4c2...      Matias      person
# 6   bcb93d9680b08656367b3682a9b4c127-c81e728d9d4c2...      Lionel      person
# 7   f9fdac801645d8b673ce785f01658a1e-c81e728d9d4c2...      Miguel      person
# 8   822736b3fe21296f7d5c35a5e13d3ca3-c81e728d9d4c2...     Luciana      person
# 9   a5b6fc8ad5a79c2b57af4137389a7b6b-c81e728d9d4c2...     Marcelo      person
# 18  79b60482d282d7fe48287ef484be2d31-a87ff679a2f3e...     Jonatan      person
# 19  6bb28c0af81044a5f2bf023eb7f253e2-a87ff679a2f3e...       Lucas      person
# 20  51280652ee54bf9e25636110b859faf5-a87ff679a2f3e...    Fernando      person
# 21  f6b8790fd8dcb51f4ccec2e19f6db824-a87ff679a2f3e...      Gastón      person
# 22  533348a1f755b9512eb8b91aa07a300a-a87ff679a2f3e...      Andrea      person
# 23  8ebb5bf7f39a9ec7304a17cdf5063df9-a87ff679a2f3e...      Martin      person
#
#    person_category person_gender  person_age  person_experience
# 2           junior        female        23.0                3.0
# 3           senior          male        44.0               11.0
# 4           senior          male        45.0               16.0
# 5           junior          male        25.0                2.0
# 6      semi-senior          male        35.0                3.0
# 7           junior          male        24.0                2.0
# 8      semi-senior        female        34.0                4.0
# 9           senior          male        41.0               12.0
# 18          senior          male        33.0                7.0
# 19          senior          male        35.0                6.0
# 20     semi-senior          male        28.0                4.0
# 21     semi-senior          male        27.0                3.0
# 22     semi-senior        female        27.0                3.0
# 23          senior          male        34.0                5.0

# %%
#Definimos un dataset de tecnologias
technologies = nodos[nodos["n.type"] == "technologies"]
#Mejoramos los nombres
technologies.columns = technologies.columns.str.replace('n.id', 'technology_id')
technologies.columns = technologies.columns.str.replace('name_node_a', 'technology_name')
technologies.columns = technologies.columns.str.replace('n.type', 'technology_type')
technologies = technologies.drop(columns='n.category',axis=1)
technologies = technologies.drop(columns='n.gender',axis=1)
technologies = technologies.drop(columns='n.age',axis=1)
technologies = technologies.drop(columns='n.experience',axis=1)
technologies
# Out:
#                                         technology_id  \
# 11  ff64319904f4832ee19df96250276033-c81e728d9d4c2...
# 12  17fc99d3f691680db18b948f4b9a4547-a87ff679a2f3e...
# 13  31985bb925fa449ee8d01350cb2f008d-a87ff679a2f3e...
# 14  e75155594a0fd8405cde512bd9aaedad-a87ff679a2f3e...
# 15  c75df195acce9063a96459de85bc72b9-a87ff679a2f3e...
# ..                                                ...
# 87  ffeffd6344800bfc7214b6d7ef83ea10-a87ff679a2f3e...
# 88  362da8a51e150638e6981d0771534c8e-a87ff679a2f3e...
# 89  263db3933c2cb8e9b139373fdd57defb-a87ff679a2f3e...
# 90  de1284aa9ed99ad37c8259c2028b161c-a87ff679a2f3e...
# 91  bb906c05289c29654b54a94ced2e697c-a87ff679a2f3e...
#
#                                 technology_name technology_type
# 11                                      Inst DB    technologies
# 12                                   AWS Lambda    technologies
# 13                                  AWS Kinesis    technologies
# 14                                     DynamoDB    technologies
# 15  Monta un Cluster Hadoop Big Data desde Cero    technologies
# ..                                          ...             ...
# 87                                       talend    technologies
# 88                                      pentaho    technologies
# 89                                  Integracion    technologies
# 90                                          ODI    technologies
# 91                                    Lenguajes    technologies
#
# [67 rows x 3 columns]

# %%
#vamos a unir los dataset para analizarlos 
resultante = skills.merge(relaciones, left_on='skill_id', right_on='id_node_b')
resultante = resultante[['skill_id','skill_name','skill_type','id_node_a']]
resultante.set_index('id_node_a')
resultante
# Out:
#                                              skill_id        skill_name  \
# 0   6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e...    Data Scientist
# 1   6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e...    Data Scientist
# 2   6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e...    Data Scientist
# 3   720d1c3fee7aef666abe0c50a9a7cde1-a87ff679a2f3e...               DBA
# 4   720d1c3fee7aef666abe0c50a9a7cde1-a87ff679a2f3e...               DBA
# 5   720d1c3fee7aef666abe0c50a9a7cde1-a87ff679a2f3e...               DBA
# 6   720d1c3fee7aef666abe0c50a9a7cde1-a87ff679a2f3e...               DBA
# 7   720d1c3fee7aef666abe0c50a9a7cde1-a87ff679a2f3e...               DBA
# 8   ac894b03f495d68a60f2d786e79aa1e3-a87ff679a2f3e...    Data Architect
# 9   7d49add0d0c4fa941e927e85ad5226f2-a87ff679a2f3e...         Developer
# 10  7d49add0d0c4fa941e927e85ad5226f2-a87ff679a2f3e...         Developer
# 11  7d49add0d0c4fa941e927e85ad5226f2-a87ff679a2f3e...         Developer
# 12  7d49add0d0c4fa941e927e85ad5226f2-a87ff679a2f3e...         Developer
# 13  7d49add0d0c4fa941e927e85ad5226f2-a87ff679a2f3e...         Developer
# 14  7d49add0d0c4fa941e927e85ad5226f2-a87ff679a2f3e...         Developer
# 15  7d49add0d0c4fa941e927e85ad5226f2-a87ff679a2f3e...         Developer
# 16  4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e...  Technical Leader
# 17  4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e...  Technical Leader
# 18  4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e...  Technical Leader
# 19  a8cea7ec2709db07e628b80e2dafa2b6-a87ff679a2f3e...     Data Engineer
#
#    skill_type                                          id_node_a
# 0       skill  dd05195a0be8a3102470e9d6955e49be-c81e728d9d4c2...
# 1       skill  51280652ee54bf9e25636110b859faf5-a87ff679a2f3e...
# 2       skill  8ebb5bf7f39a9ec7304a17cdf5063df9-a87ff679a2f3e...
# 3       skill  a5b6fc8ad5a79c2b57af4137389a7b6b-c81e728d9d4c2...
# 4       skill  dd05195a0be8a3102470e9d6955e49be-c81e728d9d4c2...
# 5       skill  79b60482d282d7fe48287ef484be2d31-a87ff679a2f3e...
# 6       skill  6bb28c0af81044a5f2bf023eb7f253e2-a87ff679a2f3e...
# 7       skill  f6b8790fd8dcb51f4ccec2e19f6db824-a87ff679a2f3e...
# 8       skill  dd05195a0be8a3102470e9d6955e49be-c81e728d9d4c2...
# 9       skill  1ae7f988daa7541df8d9eba692e3949d-c81e728d9d4c2...
# 10      skill  e726642e86168eacfeee3fa8c4da012e-c81e728d9d4c2...
# 11      skill  10c246e19e023f335e179b937c28a6da-c81e728d9d4c2...
# 12      skill  f9fdac801645d8b673ce785f01658a1e-c81e728d9d4c2...
# 13      skill  822736b3fe21296f7d5c35a5e13d3ca3-c81e728d9d4c2...
# 14      skill  dd05195a0be8a3102470e9d6955e49be-c81e728d9d4c2...
# 15      skill  533348a1f755b9512eb8b91aa07a300a-a87ff679a2f3e...
# 16      skill  f496c7004f07dba853bf8fadc28c9650-c81e728d9d4c2...
# 17      skill  bcb93d9680b08656367b3682a9b4c127-c81e728d9d4c2...
# 18      skill  dd05195a0be8a3102470e9d6955e49be-c81e728d9d4c2...
# 19      skill  dd05195a0be8a3102470e9d6955e49be-c81e728d9d4c2...

# %%
# Vamos a vincular con las personas
resultante = resultante.merge(persons, left_on='id_node_a', right_on='person_id')
resultante.merge(persons, left_on='id_node_a', right_on='person_id')
# Out:
#                                              skill_id        skill_name  \
# 0   6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e...    Data Scientist
# 1   6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e...    Data Scientist
# 2   720d1c3fee7aef666abe0c50a9a7cde1-a87ff679a2f3e...               DBA
# 3   720d1c3fee7aef666abe0c50a9a7cde1-a87ff679a2f3e...               DBA
# 4   720d1c3fee7aef666abe0c50a9a7cde1-a87ff679a2f3e...               DBA
# 5   720d1c3fee7aef666abe0c50a9a7cde1-a87ff679a2f3e...               DBA
# 6   7d49add0d0c4fa941e927e85ad5226f2-a87ff679a2f3e...         Developer
# 7   7d49add0d0c4fa941e927e85ad5226f2-a87ff679a2f3e...         Developer
# 8   7d49add0d0c4fa941e927e85ad5226f2-a87ff679a2f3e...         Developer
# 9   7d49add0d0c4fa941e927e85ad5226f2-a87ff679a2f3e...         Developer
# 10  7d49add0d0c4fa941e927e85ad5226f2-a87ff679a2f3e...         Developer
# 11  7d49add0d0c4fa941e927e85ad5226f2-a87ff679a2f3e...         Developer
# 12  4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e...  Technical Leader
# 13  4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e...  Technical Leader
#
#    skill_type                                          id_node_a  \
# 0       skill  51280652ee54bf9e25636110b859faf5-a87ff679a2f3e...
# 1       skill  8ebb5bf7f39a9ec7304a17cdf5063df9-a87ff679a2f3e...
# 2       skill  a5b6fc8ad5a79c2b57af4137389a7b6b-c81e728d9d4c2...
# 3       skill  79b60482d282d7fe48287ef484be2d31-a87ff679a2f3e...
# 4       skill  6bb28c0af81044a5f2bf023eb7f253e2-a87ff679a2f3e...
# 5       skill  f6b8790fd8dcb51f4ccec2e19f6db824-a87ff679a2f3e...
# 6       skill  1ae7f988daa7541df8d9eba692e3949d-c81e728d9d4c2...
# 7       skill  e726642e86168eacfeee3fa8c4da012e-c81e728d9d4c2...
# 8       skill  10c246e19e023f335e179b937c28a6da-c81e728d9d4c2...
# 9       skill  f9fdac801645d8b673ce785f01658a1e-c81e728d9d4c2...
# 10      skill  822736b3fe21296f7d5c35a5e13d3ca3-c81e728d9d4c2...
# 11      skill  533348a1f755b9512eb8b91aa07a300a-a87ff679a2f3e...
# 12      skill  f496c7004f07dba853bf8fadc28c9650-c81e728d9d4c2...
# 13      skill  bcb93d9680b08656367b3682a9b4c127-c81e728d9d4c2...
#
#                                           person_id_x person_name_x  \
# 0   51280652ee54bf9e25636110b859faf5-a87ff679a2f3e...      Fernando
# 1   8ebb5bf7f39a9ec7304a17cdf5063df9-a87ff679a2f3e...        Martin
# 2   a5b6fc8ad5a79c2b57af4137389a7b6b-c81e728d9d4c2...       Marcelo
# 3   79b60482d282d7fe48287ef484be2d31-a87ff679a2f3e...       Jonatan
# 4   6bb28c0af81044a5f2bf023eb7f253e2-a87ff679a2f3e...         Lucas
# 5   f6b8790fd8dcb51f4ccec2e19f6db824-a87ff679a2f3e...        Gastón
# 6   1ae7f988daa7541df8d9eba692e3949d-c81e728d9d4c2...       Marcela
# 7   e726642e86168eacfeee3fa8c4da012e-c81e728d9d4c2...      Leonardo
# 8   10c246e19e023f335e179b937c28a6da-c81e728d9d4c2...        Matias
# 9   f9fdac801645d8b673ce785f01658a1e-c81e728d9d4c2...        Miguel
# 10  822736b3fe21296f7d5c35a5e13d3ca3-c81e728d9d4c2...       Luciana
# 11  533348a1f755b9512eb8b91aa07a300a-a87ff679a2f3e...        Andrea
# 12  f496c7004f07dba853bf8fadc28c9650-c81e728d9d4c2...        Daniel
# 13  bcb93d9680b08656367b3682a9b4c127-c81e728d9d4c2...        Lionel
#
#    person_type_x person_category_x person_gender_x  person_age_x  \
# 0         person       semi-senior            male          28.0
# 1         person            senior            male          34.0
# 2         person            senior            male          41.0
# 3         person            senior            male          33.0
# 4         person            senior            male          35.0
# 5         person       semi-senior            male          27.0
# 6         person            junior          female          23.0
# 7         person            senior            male          45.0
# 8         person            junior            male          25.0
# 9         person            junior            male          24.0
# 10        person       semi-senior          female          34.0
# 11        person       semi-senior          female          27.0
# 12        person            senior            male          44.0
# 13        person       semi-senior            male          35.0
#
#     person_experience_x                                        person_id_y  \
# 0                   4.0  51280652ee54bf9e25636110b859faf5-a87ff679a2f3e...
# 1                   5.0  8ebb5bf7f39a9ec7304a17cdf5063df9-a87ff679a2f3e...
# 2                  12.0  a5b6fc8ad5a79c2b57af4137389a7b6b-c81e728d9d4c2...
# 3                   7.0  79b60482d282d7fe48287ef484be2d31-a87ff679a2f3e...
# 4                   6.0  6bb28c0af81044a5f2bf023eb7f253e2-a87ff679a2f3e...
# 5                   3.0  f6b8790fd8dcb51f4ccec2e19f6db824-a87ff679a2f3e...
# 6                   3.0  1ae7f988daa7541df8d9eba692e3949d-c81e728d9d4c2...
# 7                  16.0  e726642e86168eacfeee3fa8c4da012e-c81e728d9d4c2...
# 8                   2.0  10c246e19e023f335e179b937c28a6da-c81e728d9d4c2...
# 9                   2.0  f9fdac801645d8b673ce785f01658a1e-c81e728d9d4c2...
# 10                  4.0  822736b3fe21296f7d5c35a5e13d3ca3-c81e728d9d4c2...
# 11                  3.0  533348a1f755b9512eb8b91aa07a300a-a87ff679a2f3e...
# 12                 11.0  f496c7004f07dba853bf8fadc28c9650-c81e728d9d4c2...
# 13                  3.0  bcb93d9680b08656367b3682a9b4c127-c81e728d9d4c2...
#
#    person_name_y person_type_y person_category_y person_gender_y  \
# 0       Fernando        person       semi-senior            male
# 1         Martin        person            senior            male
# 2        Marcelo        person            senior            male
# 3        Jonatan        person            senior            male
# 4          Lucas        person            senior            male
# 5         Gastón        person       semi-senior            male
# 6        Marcela        person            junior          female
# 7       Leonardo        person            senior            male
# 8         Matias        person            junior            male
# 9         Miguel        person            junior            male
# 10       Luciana        person       semi-senior          female
# 11        Andrea        person       semi-senior          female
# 12        Daniel        person            senior            male
# 13        Lionel        person       semi-senior            male
#
#     person_age_y  person_experience_y
# 0           28.0                  4.0
# 1           34.0                  5.0
# 2           41.0                 12.0
# 3           33.0                  7.0
# 4           35.0                  6.0
# 5           27.0                  3.0
# 6           23.0                  3.0
# 7           45.0                 16.0
# 8           25.0                  2.0
# 9           24.0                  2.0
# 10          34.0                  4.0
# 11          27.0                  3.0
# 12          44.0                 11.0
# 13          35.0                  3.0

# %%
# Quitamos la columna que nos sirvió para las relaciones
resultante = resultante.drop(columns='id_node_a',axis=1)
resultante
# Out:
#                                              skill_id        skill_name  \
# 0   6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e...    Data Scientist
# 1   6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e...    Data Scientist
# 2   720d1c3fee7aef666abe0c50a9a7cde1-a87ff679a2f3e...               DBA
# 3   720d1c3fee7aef666abe0c50a9a7cde1-a87ff679a2f3e...               DBA
# 4   720d1c3fee7aef666abe0c50a9a7cde1-a87ff679a2f3e...               DBA
# 5   720d1c3fee7aef666abe0c50a9a7cde1-a87ff679a2f3e...               DBA
# 6   7d49add0d0c4fa941e927e85ad5226f2-a87ff679a2f3e...         Developer
# 7   7d49add0d0c4fa941e927e85ad5226f2-a87ff679a2f3e...         Developer
# 8   7d49add0d0c4fa941e927e85ad5226f2-a87ff679a2f3e...         Developer
# 9   7d49add0d0c4fa941e927e85ad5226f2-a87ff679a2f3e...         Developer
# 10  7d49add0d0c4fa941e927e85ad5226f2-a87ff679a2f3e...         Developer
# 11  7d49add0d0c4fa941e927e85ad5226f2-a87ff679a2f3e...         Developer
# 12  4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e...  Technical Leader
# 13  4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e...  Technical Leader
#
#    skill_type                                          person_id person_name  \
# 0       skill  51280652ee54bf9e25636110b859faf5-a87ff679a2f3e...    Fernando
# 1       skill  8ebb5bf7f39a9ec7304a17cdf5063df9-a87ff679a2f3e...      Martin
# 2       skill  a5b6fc8ad5a79c2b57af4137389a7b6b-c81e728d9d4c2...     Marcelo
# 3       skill  79b60482d282d7fe48287ef484be2d31-a87ff679a2f3e...     Jonatan
# 4       skill  6bb28c0af81044a5f2bf023eb7f253e2-a87ff679a2f3e...       Lucas
# 5       skill  f6b8790fd8dcb51f4ccec2e19f6db824-a87ff679a2f3e...      Gastón
# 6       skill  1ae7f988daa7541df8d9eba692e3949d-c81e728d9d4c2...     Marcela
# 7       skill  e726642e86168eacfeee3fa8c4da012e-c81e728d9d4c2...    Leonardo
# 8       skill  10c246e19e023f335e179b937c28a6da-c81e728d9d4c2...      Matias
# 9       skill  f9fdac801645d8b673ce785f01658a1e-c81e728d9d4c2...      Miguel
# 10      skill  822736b3fe21296f7d5c35a5e13d3ca3-c81e728d9d4c2...     Luciana
# 11      skill  533348a1f755b9512eb8b91aa07a300a-a87ff679a2f3e...      Andrea
# 12      skill  f496c7004f07dba853bf8fadc28c9650-c81e728d9d4c2...      Daniel
# 13      skill  bcb93d9680b08656367b3682a9b4c127-c81e728d9d4c2...      Lionel
#
#    person_type person_category person_gender  person_age  person_experience
# 0       person     semi-senior          male        28.0                4.0
# 1       person          senior          male        34.0                5.0
# 2       person          senior          male        41.0               12.0
# 3       person          senior          male        33.0                7.0
# 4       person          senior          male        35.0                6.0
# 5       person     semi-senior          male        27.0                3.0
# 6       person          junior        female        23.0                3.0
# 7       person          senior          male        45.0               16.0
# 8       person          junior          male        25.0                2.0
# 9       person          junior          male        24.0                2.0
# 10      person     semi-senior        female        34.0                4.0
# 11      person     semi-senior        female        27.0                3.0
# 12      person          senior          male        44.0               11.0
# 13      person     semi-senior          male        35.0                3.0

# %%
# Vamos a vincular con las relaciones de las tecnologias
resultante = resultante.merge(relaciones[['id_node_a','id_node_b']], left_on='person_id', right_on='id_node_a')
relaciones["name_node_a"].unique()
resultante = resultante.merge(technologies, left_on='id_node_b', right_on='technology_id')
resultante
# Out:
#                                              skill_id        skill_name  \
# 0   6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e...    Data Scientist
# 1   7d49add0d0c4fa941e927e85ad5226f2-a87ff679a2f3e...         Developer
# 2   6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e...    Data Scientist
# 3   6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e...    Data Scientist
# 4   7d49add0d0c4fa941e927e85ad5226f2-a87ff679a2f3e...         Developer
# ..                                                ...               ...
# 87  4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e...  Technical Leader
# 88  4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e...  Technical Leader
# 89  4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e...  Technical Leader
# 90  4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e...  Technical Leader
# 91  4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e...  Technical Leader
#
#    skill_type                                          person_id person_name  \
# 0       skill  51280652ee54bf9e25636110b859faf5-a87ff679a2f3e...    Fernando
# 1       skill  533348a1f755b9512eb8b91aa07a300a-a87ff679a2f3e...      Andrea
# 2       skill  51280652ee54bf9e25636110b859faf5-a87ff679a2f3e...    Fernando
# 3       skill  8ebb5bf7f39a9ec7304a17cdf5063df9-a87ff679a2f3e...      Martin
# 4       skill  1ae7f988daa7541df8d9eba692e3949d-c81e728d9d4c2...     Marcela
# ..        ...                                                ...         ...
# 87      skill  bcb93d9680b08656367b3682a9b4c127-c81e728d9d4c2...      Lionel
# 88      skill  f496c7004f07dba853bf8fadc28c9650-c81e728d9d4c2...      Daniel
# 89      skill  f496c7004f07dba853bf8fadc28c9650-c81e728d9d4c2...      Daniel
# 90      skill  bcb93d9680b08656367b3682a9b4c127-c81e728d9d4c2...      Lionel
# 91      skill  bcb93d9680b08656367b3682a9b4c127-c81e728d9d4c2...      Lionel
#
#    person_type person_category person_gender  person_age  person_experience  \
# 0       person     semi-senior          male        28.0                4.0
# 1       person     semi-senior        female        27.0                3.0
# 2       person     semi-senior          male        28.0                4.0
# 3       person          senior          male        34.0                5.0
# 4       person          junior        female        23.0                3.0
# ..         ...             ...           ...         ...                ...
# 87      person     semi-senior          male        35.0                3.0
# 88      person          senior          male        44.0               11.0
# 89      person          senior          male        44.0               11.0
# 90      person     semi-senior          male        35.0                3.0
# 91      person     semi-senior          male        35.0                3.0
#
#                                             id_node_a  \
# 0   51280652ee54bf9e25636110b859faf5-a87ff679a2f3e...
# 1   533348a1f755b9512eb8b91aa07a300a-a87ff679a2f3e...
# 2   51280652ee54bf9e25636110b859faf5-a87ff679a2f3e...
# 3   8ebb5bf7f39a9ec7304a17cdf5063df9-a87ff679a2f3e...
# 4   1ae7f988daa7541df8d9eba692e3949d-c81e728d9d4c2...
# ..                                                ...
# 87  bcb93d9680b08656367b3682a9b4c127-c81e728d9d4c2...
# 88  f496c7004f07dba853bf8fadc28c9650-c81e728d9d4c2...
# 89  f496c7004f07dba853bf8fadc28c9650-c81e728d9d4c2...
# 90  bcb93d9680b08656367b3682a9b4c127-c81e728d9d4c2...
# 91  bcb93d9680b08656367b3682a9b4c127-c81e728d9d4c2...
#
#                                             id_node_b  \
# 0   17fc99d3f691680db18b948f4b9a4547-a87ff679a2f3e...
# 1   17fc99d3f691680db18b948f4b9a4547-a87ff679a2f3e...
# 2   bbbe1fbd5a476cc46c35ea4b051c1a36-a87ff679a2f3e...
# 3   bbbe1fbd5a476cc46c35ea4b051c1a36-a87ff679a2f3e...
# 4   bbbe1fbd5a476cc46c35ea4b051c1a36-a87ff679a2f3e...
# ..                                                ...
# 87  c064dffb1a0f1a937b56ee9c0c0a0b9c-a87ff679a2f3e...
# 88  d37772bf703931e76d906eaafe580293-a87ff679a2f3e...
# 89  886f0d10fd11a0fb8f50aa3b4eb4b2ba-a87ff679a2f3e...
# 90  ffeffd6344800bfc7214b6d7ef83ea10-a87ff679a2f3e...
# 91  c270de469c4c338f3eade627746305bd-a87ff679a2f3e...
#
#                                         technology_id technology_name  \
# 0   17fc99d3f691680db18b948f4b9a4547-a87ff679a2f3e...      AWS Lambda
# 1   17fc99d3f691680db18b948f4b9a4547-a87ff679a2f3e...      AWS Lambda
# 2   bbbe1fbd5a476cc46c35ea4b051c1a36-a87ff679a2f3e...          phyton
# 3   bbbe1fbd5a476cc46c35ea4b051c1a36-a87ff679a2f3e...          phyton
# 4   bbbe1fbd5a476cc46c35ea4b051c1a36-a87ff679a2f3e...          phyton
# ..                                                ...             ...
# 87  c064dffb1a0f1a937b56ee9c0c0a0b9c-a87ff679a2f3e...            unix
# 88  d37772bf703931e76d906eaafe580293-a87ff679a2f3e...              S3
# 89  886f0d10fd11a0fb8f50aa3b4eb4b2ba-a87ff679a2f3e...             EC2
# 90  ffeffd6344800bfc7214b6d7ef83ea10-a87ff679a2f3e...          talend
# 91  c270de469c4c338f3eade627746305bd-a87ff679a2f3e...           neo4j
#
#    technology_type
# 0     technologies
# 1     technologies
# 2     technologies
# 3     technologies
# 4     technologies
# ..             ...
# 87    technologies
# 88    technologies
# 89    technologies
# 90    technologies
# 91    technologies
#
# [92 rows x 15 columns]

# %%
# Quitamos la columna que nos sirvió para las relaciones
resultante = resultante.drop(columns='id_node_a',axis=1)
resultante = resultante.drop(columns='id_node_b',axis=1)
resultante
# Out:
#                                              skill_id        skill_name  \
# 0   6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e...    Data Scientist
# 1   7d49add0d0c4fa941e927e85ad5226f2-a87ff679a2f3e...         Developer
# 2   6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e...    Data Scientist
# 3   6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e...    Data Scientist
# 4   7d49add0d0c4fa941e927e85ad5226f2-a87ff679a2f3e...         Developer
# ..                                                ...               ...
# 87  4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e...  Technical Leader
# 88  4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e...  Technical Leader
# 89  4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e...  Technical Leader
# 90  4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e...  Technical Leader
# 91  4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e...  Technical Leader
#
#    skill_type                                          person_id person_name  \
# 0       skill  51280652ee54bf9e25636110b859faf5-a87ff679a2f3e...    Fernando
# 1       skill  533348a1f755b9512eb8b91aa07a300a-a87ff679a2f3e...      Andrea
# 2       skill  51280652ee54bf9e25636110b859faf5-a87ff679a2f3e...    Fernando
# 3       skill  8ebb5bf7f39a9ec7304a17cdf5063df9-a87ff679a2f3e...      Martin
# 4       skill  1ae7f988daa7541df8d9eba692e3949d-c81e728d9d4c2...     Marcela
# ..        ...                                                ...         ...
# 87      skill  bcb93d9680b08656367b3682a9b4c127-c81e728d9d4c2...      Lionel
# 88      skill  f496c7004f07dba853bf8fadc28c9650-c81e728d9d4c2...      Daniel
# 89      skill  f496c7004f07dba853bf8fadc28c9650-c81e728d9d4c2...      Daniel
# 90      skill  bcb93d9680b08656367b3682a9b4c127-c81e728d9d4c2...      Lionel
# 91      skill  bcb93d9680b08656367b3682a9b4c127-c81e728d9d4c2...      Lionel
#
#    person_type person_category person_gender  person_age  person_experience  \
# 0       person     semi-senior          male        28.0                4.0
# 1       person     semi-senior        female        27.0                3.0
# 2       person     semi-senior          male        28.0                4.0
# 3       person          senior          male        34.0                5.0
# 4       person          junior        female        23.0                3.0
# ..         ...             ...           ...         ...                ...
# 87      person     semi-senior          male        35.0                3.0
# 88      person          senior          male        44.0               11.0
# 89      person          senior          male        44.0               11.0
# 90      person     semi-senior          male        35.0                3.0
# 91      person     semi-senior          male        35.0                3.0
#
#                                         technology_id technology_name  \
# 0   17fc99d3f691680db18b948f4b9a4547-a87ff679a2f3e...      AWS Lambda
# 1   17fc99d3f691680db18b948f4b9a4547-a87ff679a2f3e...      AWS Lambda
# 2   bbbe1fbd5a476cc46c35ea4b051c1a36-a87ff679a2f3e...          phyton
# 3   bbbe1fbd5a476cc46c35ea4b051c1a36-a87ff679a2f3e...          phyton
# 4   bbbe1fbd5a476cc46c35ea4b051c1a36-a87ff679a2f3e...          phyton
# ..                                                ...             ...
# 87  c064dffb1a0f1a937b56ee9c0c0a0b9c-a87ff679a2f3e...            unix
# 88  d37772bf703931e76d906eaafe580293-a87ff679a2f3e...              S3
# 89  886f0d10fd11a0fb8f50aa3b4eb4b2ba-a87ff679a2f3e...             EC2
# 90  ffeffd6344800bfc7214b6d7ef83ea10-a87ff679a2f3e...          talend
# 91  c270de469c4c338f3eade627746305bd-a87ff679a2f3e...           neo4j
#
#    technology_type
# 0     technologies
# 1     technologies
# 2     technologies
# 3     technologies
# 4     technologies
# ..             ...
# 87    technologies
# 88    technologies
# 89    technologies
# 90    technologies
# 91    technologies
#
# [92 rows x 13 columns]

# %%
# Calculamos la cantidad de tecnologias conocidas por cada persona y la almacenamos en el dataset de trabajo
dataset1 = resultante.groupby(['skill_name','person_gender', 'person_category','person_name','person_age','person_experience']).size().to_frame(name='Knowledge').reset_index()
dataset1
# Out:
#           skill_name person_gender person_category person_name  person_age  \
# 0                DBA          male     semi-senior      Gastón        27.0
# 1                DBA          male          senior     Jonatan        33.0
# 2                DBA          male          senior       Lucas        35.0
# 3                DBA          male          senior     Marcelo        41.0
# 4     Data Scientist          male     semi-senior    Fernando        28.0
# 5     Data Scientist          male          senior      Martin        34.0
# 6          Developer        female          junior     Marcela        23.0
# 7          Developer        female     semi-senior      Andrea        27.0
# 8          Developer        female     semi-senior     Luciana        34.0
# 9          Developer          male          junior      Matias        25.0
# 10         Developer          male          junior      Miguel        24.0
# 11         Developer          male          senior    Leonardo        45.0
# 12  Technical Leader          male     semi-senior      Lionel        35.0
# 13  Technical Leader          male          senior      Daniel        44.0
#
#     person_experience  Knowledge
# 0                 3.0          3
# 1                 7.0          6
# 2                 6.0          4
# 3                12.0          7
# 4                 4.0          9
# 5                 5.0          4
# 6                 3.0          5
# 7                 3.0         11
# 8                 4.0          4
# 9                 2.0          4
# 10                2.0          4
# 11               16.0          4
# 12                3.0         13
# 13               11.0         14

# %%
#Usaremos este dataset para avanzar con los aspectos de Aprendizaje Automático
dataset1
# Out:
#           skill_name person_gender person_category person_name  person_age  \
# 0                DBA          male     semi-senior      Gastón        27.0
# 1                DBA          male          senior     Jonatan        33.0
# 2                DBA          male          senior       Lucas        35.0
# 3                DBA          male          senior     Marcelo        41.0
# 4     Data Scientist          male     semi-senior    Fernando        28.0
# 5     Data Scientist          male          senior      Martin        34.0
# 6          Developer        female          junior     Marcela        23.0
# 7          Developer        female     semi-senior      Andrea        27.0
# 8          Developer        female     semi-senior     Luciana        34.0
# 9          Developer          male          junior      Matias        25.0
# 10         Developer          male          junior      Miguel        24.0
# 11         Developer          male          senior    Leonardo        45.0
# 12  Technical Leader          male     semi-senior      Lionel        35.0
# 13  Technical Leader          male          senior      Daniel        44.0
#
#     person_experience  Knowledge
# 0                 3.0          3
# 1                 7.0          6
# 2                 6.0          4
# 3                12.0          7
# 4                 4.0          9
# 5                 5.0          4
# 6                 3.0          5
# 7                 3.0         11
# 8                 4.0          4
# 9                 2.0          4
# 10                2.0          4
# 11               16.0          4
# 12                3.0         13
# 13               11.0         14

# %%
#Listamos las tecnologías para crear columnas adicionales
newColumns = resultante['technology_name'].unique()
newColumns
# Out:
# array(['AWS Lambda', 'phyton', 'Docker', 'Kubernetes', 'Linux', 'Spark',
#        'MySQL', 'SQL Server', 'R', 'Vertica', 'ODI', 'windows',
#        'Golden Gate', 'Oracle', 'Oracle Cloud', 'SQL', 'java', 'pentaho',
#        'Hadoop', 'MariaDB', 'Redis', 'Azure', 'Google cloud',
#        'PostgreSQL', 'unix', 'S3', 'EC2', 'talend', 'neo4j'], dtype=object)

# %%
#Creamos un dataframe con los nombres de las nuevas columnas
dataTechnologies = pd.DataFrame(resultante,
 columns=newColumns, index=resultante['skill_id'])
dataTechnologies
# Out:
#                                                     AWS Lambda  phyton  \
# skill_id
# 6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e7...         NaN     NaN
# 7d49add0d0c4fa941e927e85ad5226f2-a87ff679a2f3e7...         NaN     NaN
# 6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e7...         NaN     NaN
# 6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e7...         NaN     NaN
# 7d49add0d0c4fa941e927e85ad5226f2-a87ff679a2f3e7...         NaN     NaN
# ...                                                        ...     ...
# 4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e7...         NaN     NaN
# 4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e7...         NaN     NaN
# 4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e7...         NaN     NaN
# 4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e7...         NaN     NaN
# 4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e7...         NaN     NaN
#
#                                                     Docker  Kubernetes  Linux  \
# skill_id
# 6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e7...     NaN         NaN    NaN
# 7d49add0d0c4fa941e927e85ad5226f2-a87ff679a2f3e7...     NaN         NaN    NaN
# 6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e7...     NaN         NaN    NaN
# 6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e7...     NaN         NaN    NaN
# 7d49add0d0c4fa941e927e85ad5226f2-a87ff679a2f3e7...     NaN         NaN    NaN
# ...                                                    ...         ...    ...
# 4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e7...     NaN         NaN    NaN
# 4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e7...     NaN         NaN    NaN
# 4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e7...     NaN         NaN    NaN
# 4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e7...     NaN         NaN    NaN
# 4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e7...     NaN         NaN    NaN
#
#                                                     Spark  MySQL  SQL Server  \
# skill_id
# 6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e7...    NaN    NaN         NaN
# 7d49add0d0c4fa941e927e85ad5226f2-a87ff679a2f3e7...    NaN    NaN         NaN
# 6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e7...    NaN    NaN         NaN
# 6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e7...    NaN    NaN         NaN
# 7d49add0d0c4fa941e927e85ad5226f2-a87ff679a2f3e7...    NaN    NaN         NaN
# ...                                                   ...    ...         ...
# 4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e7...    NaN    NaN         NaN
# 4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e7...    NaN    NaN         NaN
# 4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e7...    NaN    NaN         NaN
# 4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e7...    NaN    NaN         NaN
# 4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e7...    NaN    NaN         NaN
#
#                                                      R  Vertica  ...  MariaDB  \
# skill_id                                                         ...
# 6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e7... NaN      NaN  ...      NaN
# 7d49add0d0c4fa941e927e85ad5226f2-a87ff679a2f3e7... NaN      NaN  ...      NaN
# 6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e7... NaN      NaN  ...      NaN
# 6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e7... NaN      NaN  ...      NaN
# 7d49add0d0c4fa941e927e85ad5226f2-a87ff679a2f3e7... NaN      NaN  ...      NaN
# ...                                                 ..      ...  ...      ...
# 4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e7... NaN      NaN  ...      NaN
# 4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e7... NaN      NaN  ...      NaN
# 4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e7... NaN      NaN  ...      NaN
# 4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e7... NaN      NaN  ...      NaN
# 4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e7... NaN      NaN  ...      NaN
#
#                                                     Redis  Azure  \
# skill_id
# 6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e7...    NaN    NaN
# 7d49add0d0c4fa941e927e85ad5226f2-a87ff679a2f3e7...    NaN    NaN
# 6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e7...    NaN    NaN
# 6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e7...    NaN    NaN
# 7d49add0d0c4fa941e927e85ad5226f2-a87ff679a2f3e7...    NaN    NaN
# ...                                                   ...    ...
# 4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e7...    NaN    NaN
# 4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e7...    NaN    NaN
# 4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e7...    NaN    NaN
# 4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e7...    NaN    NaN
# 4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e7...    NaN    NaN
#
#                                                     Google cloud  PostgreSQL  \
# skill_id
# 6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e7...           NaN         NaN
# 7d49add0d0c4fa941e927e85ad5226f2-a87ff679a2f3e7...           NaN         NaN
# 6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e7...           NaN         NaN
# 6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e7...           NaN         NaN
# 7d49add0d0c4fa941e927e85ad5226f2-a87ff679a2f3e7...           NaN         NaN
# ...                                                          ...         ...
# 4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e7...           NaN         NaN
# 4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e7...           NaN         NaN
# 4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e7...           NaN         NaN
# 4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e7...           NaN         NaN
# 4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e7...           NaN         NaN
#
#                                                     unix  S3  EC2  talend  \
# skill_id
# 6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e7...   NaN NaN  NaN     NaN
# 7d49add0d0c4fa941e927e85ad5226f2-a87ff679a2f3e7...   NaN NaN  NaN     NaN
# 6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e7...   NaN NaN  NaN     NaN
# 6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e7...   NaN NaN  NaN     NaN
# 7d49add0d0c4fa941e927e85ad5226f2-a87ff679a2f3e7...   NaN NaN  NaN     NaN
# ...                                                  ...  ..  ...     ...
# 4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e7...   NaN NaN  NaN     NaN
# 4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e7...   NaN NaN  NaN     NaN
# 4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e7...   NaN NaN  NaN     NaN
# 4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e7...   NaN NaN  NaN     NaN
# 4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e7...   NaN NaN  NaN     NaN
#
#                                                     neo4j
# skill_id
# 6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e7...    NaN
# 7d49add0d0c4fa941e927e85ad5226f2-a87ff679a2f3e7...    NaN
# 6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e7...    NaN
# 6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e7...    NaN
# 7d49add0d0c4fa941e927e85ad5226f2-a87ff679a2f3e7...    NaN
# ...                                                   ...
# 4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e7...    NaN
# 4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e7...    NaN
# 4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e7...    NaN
# 4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e7...    NaN
# 4bc67c9e6001ce92edd195848030cb53-a87ff679a2f3e7...    NaN
#
# [92 rows x 29 columns]

# %%
#Creamos un dataset para indicar las tecnologias
dataset2 = resultante.merge(dataTechnologies, left_on='skill_id', right_on='skill_id')
dataset2
# Out:
#                                                skill_id      skill_name  \
# 0     6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e...  Data Scientist
# 1     6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e...  Data Scientist
# 2     6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e...  Data Scientist
# 3     6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e...  Data Scientist
# 4     6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e...  Data Scientist
# ...                                                 ...             ...
# 2317  720d1c3fee7aef666abe0c50a9a7cde1-a87ff679a2f3e...             DBA
# 2318  720d1c3fee7aef666abe0c50a9a7cde1-a87ff679a2f3e...             DBA
# 2319  720d1c3fee7aef666abe0c50a9a7cde1-a87ff679a2f3e...             DBA
# 2320  720d1c3fee7aef666abe0c50a9a7cde1-a87ff679a2f3e...             DBA
# 2321  720d1c3fee7aef666abe0c50a9a7cde1-a87ff679a2f3e...             DBA
#
#      skill_type                                          person_id  \
# 0         skill  51280652ee54bf9e25636110b859faf5-a87ff679a2f3e...
# 1         skill  51280652ee54bf9e25636110b859faf5-a87ff679a2f3e...
# 2         skill  51280652ee54bf9e25636110b859faf5-a87ff679a2f3e...
# 3         skill  51280652ee54bf9e25636110b859faf5-a87ff679a2f3e...
# 4         skill  51280652ee54bf9e25636110b859faf5-a87ff679a2f3e...
# ...         ...                                                ...
# 2317      skill  f6b8790fd8dcb51f4ccec2e19f6db824-a87ff679a2f3e...
# 2318      skill  f6b8790fd8dcb51f4ccec2e19f6db824-a87ff679a2f3e...
# 2319      skill  f6b8790fd8dcb51f4ccec2e19f6db824-a87ff679a2f3e...
# 2320      skill  f6b8790fd8dcb51f4ccec2e19f6db824-a87ff679a2f3e...
# 2321      skill  f6b8790fd8dcb51f4ccec2e19f6db824-a87ff679a2f3e...
#
#      person_name person_type person_category person_gender  person_age  \
# 0       Fernando      person     semi-senior          male        28.0
# 1       Fernando      person     semi-senior          male        28.0
# 2       Fernando      person     semi-senior          male        28.0
# 3       Fernando      person     semi-senior          male        28.0
# 4       Fernando      person     semi-senior          male        28.0
# ...          ...         ...             ...           ...         ...
# 2317      Gastón      person     semi-senior          male        27.0
# 2318      Gastón      person     semi-senior          male        27.0
# 2319      Gastón      person     semi-senior          male        27.0
# 2320      Gastón      person     semi-senior          male        27.0
# 2321      Gastón      person     semi-senior          male        27.0
#
#       person_experience  ... MariaDB Redis Azure  Google cloud  PostgreSQL  \
# 0                   4.0  ...     NaN   NaN   NaN           NaN         NaN
# 1                   4.0  ...     NaN   NaN   NaN           NaN         NaN
# 2                   4.0  ...     NaN   NaN   NaN           NaN         NaN
# 3                   4.0  ...     NaN   NaN   NaN           NaN         NaN
# 4                   4.0  ...     NaN   NaN   NaN           NaN         NaN
# ...                 ...  ...     ...   ...   ...           ...         ...
# 2317                3.0  ...     NaN   NaN   NaN           NaN         NaN
# 2318                3.0  ...     NaN   NaN   NaN           NaN         NaN
# 2319                3.0  ...     NaN   NaN   NaN           NaN         NaN
# 2320                3.0  ...     NaN   NaN   NaN           NaN         NaN
# 2321                3.0  ...     NaN   NaN   NaN           NaN         NaN
#
#       unix  S3  EC2  talend  neo4j
# 0      NaN NaN  NaN     NaN    NaN
# 1      NaN NaN  NaN     NaN    NaN
# 2      NaN NaN  NaN     NaN    NaN
# 3      NaN NaN  NaN     NaN    NaN
# 4      NaN NaN  NaN     NaN    NaN
# ...    ...  ..  ...     ...    ...
# 2317   NaN NaN  NaN     NaN    NaN
# 2318   NaN NaN  NaN     NaN    NaN
# 2319   NaN NaN  NaN     NaN    NaN
# 2320   NaN NaN  NaN     NaN    NaN
# 2321   NaN NaN  NaN     NaN    NaN
#
# [2322 rows x 42 columns]

# %%
# Eliminamos los duplicados 
dataset2 = dataset2.drop_duplicates()
dataset2
# Out:
#                                                skill_id      skill_name  \
# 0     6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e...  Data Scientist
# 13    6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e...  Data Scientist
# 26    6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e...  Data Scientist
# 39    6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e...  Data Scientist
# 52    6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e...  Data Scientist
# ...                                                 ...             ...
# 2222  720d1c3fee7aef666abe0c50a9a7cde1-a87ff679a2f3e...             DBA
# 2242  720d1c3fee7aef666abe0c50a9a7cde1-a87ff679a2f3e...             DBA
# 2262  720d1c3fee7aef666abe0c50a9a7cde1-a87ff679a2f3e...             DBA
# 2282  720d1c3fee7aef666abe0c50a9a7cde1-a87ff679a2f3e...             DBA
# 2302  720d1c3fee7aef666abe0c50a9a7cde1-a87ff679a2f3e...             DBA
#
#      skill_type                                          person_id  \
# 0         skill  51280652ee54bf9e25636110b859faf5-a87ff679a2f3e...
# 13        skill  51280652ee54bf9e25636110b859faf5-a87ff679a2f3e...
# 26        skill  8ebb5bf7f39a9ec7304a17cdf5063df9-a87ff679a2f3e...
# 39        skill  51280652ee54bf9e25636110b859faf5-a87ff679a2f3e...
# 52        skill  51280652ee54bf9e25636110b859faf5-a87ff679a2f3e...
# ...         ...                                                ...
# 2222      skill  6bb28c0af81044a5f2bf023eb7f253e2-a87ff679a2f3e...
# 2242      skill  a5b6fc8ad5a79c2b57af4137389a7b6b-c81e728d9d4c2...
# 2262      skill  79b60482d282d7fe48287ef484be2d31-a87ff679a2f3e...
# 2282      skill  79b60482d282d7fe48287ef484be2d31-a87ff679a2f3e...
# 2302      skill  f6b8790fd8dcb51f4ccec2e19f6db824-a87ff679a2f3e...
#
#      person_name person_type person_category person_gender  person_age  \
# 0       Fernando      person     semi-senior          male        28.0
# 13      Fernando      person     semi-senior          male        28.0
# 26        Martin      person          senior          male        34.0
# 39      Fernando      person     semi-senior          male        28.0
# 52      Fernando      person     semi-senior          male        28.0
# ...          ...         ...             ...           ...         ...
# 2222       Lucas      person          senior          male        35.0
# 2242     Marcelo      person          senior          male        41.0
# 2262     Jonatan      person          senior          male        33.0
# 2282     Jonatan      person          senior          male        33.0
# 2302      Gastón      person     semi-senior          male        27.0
#
#       person_experience  ... MariaDB Redis Azure  Google cloud  PostgreSQL  \
# 0                   4.0  ...     NaN   NaN   NaN           NaN         NaN
# 13                  4.0  ...     NaN   NaN   NaN           NaN         NaN
# 26                  5.0  ...     NaN   NaN   NaN           NaN         NaN
# 39                  4.0  ...     NaN   NaN   NaN           NaN         NaN
# 52                  4.0  ...     NaN   NaN   NaN           NaN         NaN
# ...                 ...  ...     ...   ...   ...           ...         ...
# 2222                6.0  ...     NaN   NaN   NaN           NaN         NaN
# 2242               12.0  ...     NaN   NaN   NaN           NaN         NaN
# 2262                7.0  ...     NaN   NaN   NaN           NaN         NaN
# 2282                7.0  ...     NaN   NaN   NaN           NaN         NaN
# 2302                3.0  ...     NaN   NaN   NaN           NaN         NaN
#
#       unix  S3  EC2  talend  neo4j
# 0      NaN NaN  NaN     NaN    NaN
# 13     NaN NaN  NaN     NaN    NaN
# 26     NaN NaN  NaN     NaN    NaN
# 39     NaN NaN  NaN     NaN    NaN
# 52     NaN NaN  NaN     NaN    NaN
# ...    ...  ..  ...     ...    ...
# 2222   NaN NaN  NaN     NaN    NaN
# 2242   NaN NaN  NaN     NaN    NaN
# 2262   NaN NaN  NaN     NaN    NaN
# 2282   NaN NaN  NaN     NaN    NaN
# 2302   NaN NaN  NaN     NaN    NaN
#
# [92 rows x 42 columns]

# %%
#Verficamos los conocimientos de una persona
dataset2[dataset2['person_name']=='Matias']
# Out:
#                                               skill_id skill_name skill_type  \
# 361  7d49add0d0c4fa941e927e85ad5226f2-a87ff679a2f3e...  Developer      skill
# 553  7d49add0d0c4fa941e927e85ad5226f2-a87ff679a2f3e...  Developer      skill
# 745  7d49add0d0c4fa941e927e85ad5226f2-a87ff679a2f3e...  Developer      skill
# 937  7d49add0d0c4fa941e927e85ad5226f2-a87ff679a2f3e...  Developer      skill
#
#                                              person_id person_name  \
# 361  10c246e19e023f335e179b937c28a6da-c81e728d9d4c2...      Matias
# 553  10c246e19e023f335e179b937c28a6da-c81e728d9d4c2...      Matias
# 745  10c246e19e023f335e179b937c28a6da-c81e728d9d4c2...      Matias
# 937  10c246e19e023f335e179b937c28a6da-c81e728d9d4c2...      Matias
#
#     person_type person_category person_gender  person_age  person_experience  \
# 361      person          junior          male        25.0                2.0
# 553      person          junior          male        25.0                2.0
# 745      person          junior          male        25.0                2.0
# 937      person          junior          male        25.0                2.0
#
#      ... MariaDB Redis Azure  Google cloud  PostgreSQL  unix  S3  EC2  talend  \
# 361  ...     NaN   NaN   NaN           NaN         NaN   NaN NaN  NaN     NaN
# 553  ...     NaN   NaN   NaN           NaN         NaN   NaN NaN  NaN     NaN
# 745  ...     NaN   NaN   NaN           NaN         NaN   NaN NaN  NaN     NaN
# 937  ...     NaN   NaN   NaN           NaN         NaN   NaN NaN  NaN     NaN
#
#      neo4j
# 361    NaN
# 553    NaN
# 745    NaN
# 937    NaN
#
# [4 rows x 42 columns]

# %%
dataset1
# Out:
#           skill_name person_gender person_category person_name  person_age  \
# 0                DBA          male     semi-senior      Gastón        27.0
# 1                DBA          male          senior     Jonatan        33.0
# 2                DBA          male          senior       Lucas        35.0
# 3                DBA          male          senior     Marcelo        41.0
# 4     Data Scientist          male     semi-senior    Fernando        28.0
# 5     Data Scientist          male          senior      Martin        34.0
# 6          Developer        female          junior     Marcela        23.0
# 7          Developer        female     semi-senior      Andrea        27.0
# 8          Developer        female     semi-senior     Luciana        34.0
# 9          Developer          male          junior      Matias        25.0
# 10         Developer          male          junior      Miguel        24.0
# 11         Developer          male          senior    Leonardo        45.0
# 12  Technical Leader          male     semi-senior      Lionel        35.0
# 13  Technical Leader          male          senior      Daniel        44.0
#
#     person_experience  Knowledge
# 0                 3.0          3
# 1                 7.0          6
# 2                 6.0          4
# 3                12.0          7
# 4                 4.0          9
# 5                 5.0          4
# 6                 3.0          5
# 7                 3.0         11
# 8                 4.0          4
# 9                 2.0          4
# 10                2.0          4
# 11               16.0          4
# 12                3.0         13
# 13               11.0         14

# %%
dataset2
# Out:
#                                                skill_id      skill_name  \
# 0     6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e...  Data Scientist
# 13    6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e...  Data Scientist
# 26    6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e...  Data Scientist
# 39    6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e...  Data Scientist
# 52    6bde45527df4be8bbb24be561e65f751-a87ff679a2f3e...  Data Scientist
# ...                                                 ...             ...
# 2222  720d1c3fee7aef666abe0c50a9a7cde1-a87ff679a2f3e...             DBA
# 2242  720d1c3fee7aef666abe0c50a9a7cde1-a87ff679a2f3e...             DBA
# 2262  720d1c3fee7aef666abe0c50a9a7cde1-a87ff679a2f3e...             DBA
# 2282  720d1c3fee7aef666abe0c50a9a7cde1-a87ff679a2f3e...             DBA
# 2302  720d1c3fee7aef666abe0c50a9a7cde1-a87ff679a2f3e...             DBA
#
#      skill_type                                          person_id  \
# 0         skill  51280652ee54bf9e25636110b859faf5-a87ff679a2f3e...
# 13        skill  51280652ee54bf9e25636110b859faf5-a87ff679a2f3e...
# 26        skill  8ebb5bf7f39a9ec7304a17cdf5063df9-a87ff679a2f3e...
# 39        skill  51280652ee54bf9e25636110b859faf5-a87ff679a2f3e...
# 52        skill  51280652ee54bf9e25636110b859faf5-a87ff679a2f3e...
# ...         ...                                                ...
# 2222      skill  6bb28c0af81044a5f2bf023eb7f253e2-a87ff679a2f3e...
# 2242      skill  a5b6fc8ad5a79c2b57af4137389a7b6b-c81e728d9d4c2...
# 2262      skill  79b60482d282d7fe48287ef484be2d31-a87ff679a2f3e...
# 2282      skill  79b60482d282d7fe48287ef484be2d31-a87ff679a2f3e...
# 2302      skill  f6b8790fd8dcb51f4ccec2e19f6db824-a87ff679a2f3e...
#
#      person_name person_type person_category person_gender  person_age  \
# 0       Fernando      person     semi-senior          male        28.0
# 13      Fernando      person     semi-senior          male        28.0
# 26        Martin      person          senior          male        34.0
# 39      Fernando      person     semi-senior          male        28.0
# 52      Fernando      person     semi-senior          male        28.0
# ...          ...         ...             ...           ...         ...
# 2222       Lucas      person          senior          male        35.0
# 2242     Marcelo      person          senior          male        41.0
# 2262     Jonatan      person          senior          male        33.0
# 2282     Jonatan      person          senior          male        33.0
# 2302      Gastón      person     semi-senior          male        27.0
#
#       person_experience  ... MariaDB Redis Azure  Google cloud  PostgreSQL  \
# 0                   4.0  ...     NaN   NaN   NaN           NaN         NaN
# 13                  4.0  ...     NaN   NaN   NaN           NaN         NaN
# 26                  5.0  ...     NaN   NaN   NaN           NaN         NaN
# 39                  4.0  ...     NaN   NaN   NaN           NaN         NaN
# 52                  4.0  ...     NaN   NaN   NaN           NaN         NaN
# ...                 ...  ...     ...   ...   ...           ...         ...
# 2222                6.0  ...     NaN   NaN   NaN           NaN         NaN
# 2242               12.0  ...     NaN   NaN   NaN           NaN         NaN
# 2262                7.0  ...     NaN   NaN   NaN           NaN         NaN
# 2282                7.0  ...     NaN   NaN   NaN           NaN         NaN
# 2302                3.0  ...     NaN   NaN   NaN           NaN         NaN
#
#       unix  S3  EC2  talend  neo4j
# 0      NaN NaN  NaN     NaN    NaN
# 13     NaN NaN  NaN     NaN    NaN
# 26     NaN NaN  NaN     NaN    NaN
# 39     NaN NaN  NaN     NaN    NaN
# 52     NaN NaN  NaN     NaN    NaN
# ...    ...  ..  ...     ...    ...
# 2222   NaN NaN  NaN     NaN    NaN
# 2242   NaN NaN  NaN     NaN    NaN
# 2262   NaN NaN  NaN     NaN    NaN
# 2282   NaN NaN  NaN     NaN    NaN
# 2302   NaN NaN  NaN     NaN    NaN
#
# [92 rows x 42 columns]

# %% [markdown]
# # Dataset para Problema de Clasificación Binario
#
# Si bien nuestro problema original es uno de clasificación múltiple, comenzaremos por tratarlo como un problema de clasificación binario, en donde nuestro objetivo será:
#
# 0 = Corresponde a una persona con poca experiencia (person_category = junior o person_category = semi-senior
#
# 1 = Corresponde a una persona con poca experiencia (person_category = senior
#
# Es decir, queremos identificar las personas con alto perfil de las que tienen poco . En base a esta definición, deben transformar el dataset para adaptarlo a un problema de clasifiación binario.
#
# ¿Cómo luce ahora el balance de clases? ¿Tomarán alguna decisión al respecto?

# %%
ds_bin = df_1
ds_bin
# Out:
# Campo name_node_a_x     name_node_b n_category  n_age  n_experience
# 8           Marcela       Developer     junior   23.0           3.0
# 9           Marcela         windows     junior   23.0           3.0
# 10          Marcela           Linux     junior   23.0           3.0
# 11          Marcela           MySQL     junior   23.0           3.0
# 12          Marcela          phyton     junior   23.0           3.0
# ..              ...             ...        ...    ...           ...
# 112          Martin  Data Scientist     senior   34.0           5.0
# 113          Martin         Vertica     senior   34.0           5.0
# 114          Martin      SQL Server     senior   34.0           5.0
# 115          Martin          phyton     senior   34.0           5.0
# 116          Martin             ODI     senior   34.0           5.0
#
# [106 rows x 5 columns]

# %%
ds_bin['n_category'].unique()
# Out:
# array(['junior', 'senior', 'semi-senior'], dtype=object)

# %%
aux = ds_bin['n_category'].str.get_dummies()

# %%
ds_bin = pd.concat([ds_bin, aux], axis=1)
ds_bin
# Out:
#     name_node_a_x     name_node_b n_category  n_age  n_experience  junior  \
# 8         Marcela       Developer     junior   23.0           3.0       1
# 9         Marcela         windows     junior   23.0           3.0       1
# 10        Marcela           Linux     junior   23.0           3.0       1
# 11        Marcela           MySQL     junior   23.0           3.0       1
# 12        Marcela          phyton     junior   23.0           3.0       1
# ..            ...             ...        ...    ...           ...     ...
# 112        Martin  Data Scientist     senior   34.0           5.0       0
# 113        Martin         Vertica     senior   34.0           5.0       0
# 114        Martin      SQL Server     senior   34.0           5.0       0
# 115        Martin          phyton     senior   34.0           5.0       0
# 116        Martin             ODI     senior   34.0           5.0       0
#
#      semi-senior  senior
# 8              0       0
# 9              0       0
# 10             0       0
# 11             0       0
# 12             0       0
# ..           ...     ...
# 112            0       1
# 113            0       1
# 114            0       1
# 115            0       1
# 116            0       1
#
# [106 rows x 8 columns]

# %% [markdown]
# Mezca Aleatória y División en Train/Test
# Finalmente, están en condiciones de dividir el dataset en Train y Test, utilizando para este último conjunto un 20% de los datos disponibles. Previo a esta división, es recomendable que mezclen los datos aleatoriamente. De este modo, deberán obtener cuatro conjuntos de datos, para cada uno de los datasets: X_train, X_test, y_train y y_test

# %%
ds_bin = ds_bin.drop(['junior','semi-senior'], axis=1)
ds_bin
# Out:
#     name_node_a_x     name_node_b n_category  n_age  n_experience  senior
# 8         Marcela       Developer     junior   23.0           3.0       0
# 9         Marcela         windows     junior   23.0           3.0       0
# 10        Marcela           Linux     junior   23.0           3.0       0
# 11        Marcela           MySQL     junior   23.0           3.0       0
# 12        Marcela          phyton     junior   23.0           3.0       0
# ..            ...             ...        ...    ...           ...     ...
# 112        Martin  Data Scientist     senior   34.0           5.0       1
# 113        Martin         Vertica     senior   34.0           5.0       1
# 114        Martin      SQL Server     senior   34.0           5.0       1
# 115        Martin          phyton     senior   34.0           5.0       1
# 116        Martin             ODI     senior   34.0           5.0       1
#
# [106 rows x 6 columns]

# %%
from sklearn.preprocessing import LabelEncoder

lb_make = LabelEncoder()

for column in ['name_node_a_x', 'name_node_b', 'n_category']:
    ds_bin[column] = lb_make.fit_transform(ds_bin[column])
ds_bin.head()
# Out:
#     name_node_a_x  name_node_b  n_category  n_age  n_experience  senior
# 8               9            4           0   23.0           3.0       0
# 9               9           32           0   23.0           3.0       0
# 10              9           11           0   23.0           3.0       0
# 11              9           13           0   23.0           3.0       0
# 12              9           29           0   23.0           3.0       0

# %%
from sklearn.utils import shuffle
ds_bin = shuffle(ds_bin)
ds_bin['senior'] = pd.to_numeric(ds_bin['senior'], downcast='float')
ds_bin
# Out:
#      name_node_a_x  name_node_b  n_category  n_age  n_experience  senior
# 19               1           22           2   44.0          11.0     1.0
# 115             11           29           2   34.0           5.0     1.0
# 69              10           25           2   41.0          12.0     1.0
# 44               6           13           1   35.0           3.0     0.0
# 37              12           13           0   25.0           2.0     0.0
# ..             ...          ...         ...    ...           ...     ...
# 107              0           10           1   27.0           3.0     0.0
# 98               3           28           1   27.0           3.0     0.0
# 25               1            9           2   44.0          11.0     1.0
# 64              10           32           2   41.0          12.0     1.0
# 63              10            2           2   41.0          12.0     1.0
#
# [106 rows x 6 columns]

# %% [markdown]
# ### Mezca Aleatória y División en Train/Test
# Finalmente, están en condiciones de dividir el dataset en Train y Test, utilizando para este último conjunto un 20% de los datos disponibles. Previo a esta división, es recomendable que mezclen los datos aleatoriamente. De este modo, deberán obtener cuatro conjuntos de datos, para cada uno de los datasets: X_train, X_test, y_train y y_test

# %% [markdown]
# # A partir de acá comienzo a probar para plotear la frontera
# Hay un par de líneas de código originales del archivo de Agustín que comenté y otras comentadas que eran para probar las líneas de código!

# %%
from sklearn.model_selection import train_test_split
#X, y = ds_bin[['name_node_a_x', 'name_node_b', 'n_age', 'n_experience']], ds_bin['senior']
X, y = ds_bin[['n_age', 'n_experience']], ds_bin['senior']
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state=0)
X_train.shape, X_test.shape
# Out:
# ((84, 2), (22, 2))

# %% [markdown]
# ## Aplicación de Modelos de Clasificación
# Una vez finalizada la etapa de preprocesamiento, se propone implementar diferentes modelos de clasificación para ambos datasets, utilizando la librería Scikit-Learn:
#
# 1. Perceptron. Utilizar el método Stochastic Gradient Descent (Recuerden mezclar aleatoriamente los datos antes de cada iteración)
# 2. K Nearest Neighbors ó K Vecinos Más Cercanos
# 3. Regresión Lineal.
# 4. Regresión Logística. Utilizar el método Stochastic Gradient Descent (Recuerden mezclar aleatoriamente los datos antes de cada iteración)
# Para cada uno de ellos, se pide responder las siguientes consignas:
#
# Utilizar dos features para graficar las clases y la frontera de decisión, siempre que sea posible.
# Agregar vector de Bias, cuando lo crean pertinente. Cuándo hace falta y cuándo no? Por qué?
# Obtener accuracy o exactitud.
# De estos tres tipos de modelos, cuál creen que es el más adecuado para nuestro caso de aplicación?
#
# Elegir el modelo que consideren que mejor aplica a nuestro problema. Para ello, recuerden que los pasos a seguir en la selección pueden esquematizarse como sigue:
#
# 1. Descripción de la Hipótesis
# ¿Cuál es nuestro problema? ¿Cómo se caracteriza? ¿Cuál es la hipótesis?
#
# 2. Selección de Regularizador
# ¿Utilizarán algún regularizador?¿Cuál?
#
# 3. Selección de Función de Costo
# ¿Cuál será la función de costo utilizada?
#
# 4. Justificación de las Selecciones
# ¿Por qué eligieron el modelo, el regularizador y la función de costo previas?
#
# Finalmente, para el modelo selecionado:
#
# Utilizar el método Grid Search, o de búsqueda exahustiva, con cross-validation para profundizar en la búsqueda y selección de hiperparámetros.
# Calcular métricas sobre el conjunto de entrenamiento y de evaluación para los mejores parámetros obtenidos:
# Accuracy o exactitud
# Reporte de clasificación
# Confusion matrix o matriz de confusión (graficar como heatmap)
# Curva ROC y área bajo la curva (AUC).
# Entregables
# El entregable de este práctico consiste en esta misma Notebook, pero con el preprocesamiento aplicado y los modelos implementados, agregando las explicaciones que crean pertinentes y las decisiones tomadas, en caso de corresponder.

# %% [markdown]
# ## 1.Aplicación de Perceptron

# %%
from sklearn.linear_model import Perceptron
from sklearn import metrics

# %%
model = Perceptron(tol=1e-3, random_state=0)
model.fit(X_train, y_train)
# Out:
# Perceptron(alpha=0.0001, class_weight=None, early_stopping=False, eta0=1.0,
#            fit_intercept=True, max_iter=1000, n_iter_no_change=5, n_jobs=None,
#            penalty=None, random_state=0, shuffle=True, tol=0.001,
#            validation_fraction=0.1, verbose=0, warm_start=False)

# %%
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# %%
from sklearn.metrics import classification_report

print(classification_report(y_train, y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        47
#          1.0       1.00      1.00      1.00        37
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84

# %%
print(classification_report(y_test, y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        14
#          1.0       1.00      1.00      1.00         8
#
#     accuracy                           1.00        22
#    macro avg       1.00      1.00      1.00        22
# weighted avg       1.00      1.00      1.00        22

# %% [markdown]
# Nueva implementacion de sklearn sobre perceptrón dentro del módulo de SGD.

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

# %%
# Always scale the input. The most convenient way is to use a pipeline. > consultar ¿porque?
#model = make_pipeline(StandardScaler(),
                    #SGDClassifier(loss="perceptron", eta0=1, learning_rate="constant", penalty=None))
model = make_pipeline(StandardScaler(),
                SGDClassifier(loss="perceptron", eta0=1,max_iter=5, learning_rate="constant", penalty=None))
model.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('standardscaler',
#                  StandardScaler(copy=True, with_mean=True, with_std=True)),
#                 ('sgdclassifier',
#                  SGDClassifier(alpha=0.0001, average=False, class_weight=None,
#                                early_stopping=False, epsilon=0.1, eta0=1,
#                                fit_intercept=True, l1_ratio=0.15,
#                                learning_rate='constant', loss='perceptron',
#                                max_iter=5, n_iter_no_change=5, n_jobs=None,
#                                penalty=None, power_t=0.5, random_state=None,
#                                shuffle=True, tol=0.001, validation_fraction=0.1,
#                                verbose=0, warm_start=False))],
#          verbose=False)

# %%
X_train2=X_train.T
X_train2
#quiero transformar n_age en un 0 y n_expereince en un 1...

X_train['n_experience']
# Out:
# 111     3.0
# 79      7.0
# 36      2.0
# 44      3.0
# 49      3.0
#        ...
# 98      3.0
# 61      4.0
# 30     16.0
# 11      3.0
# 102     3.0
# Name: n_experience, Length: 84, dtype: float64

# %%
#Pruebo, con un pequeño ejemplo que anden los métdos
#Xtrain_3=np.matrix([X_train['n_age']])
#asdf=np.array[[1,2],[3,4]]
#np.array( ((2,3), (3, 5)) )
#
a=np.matrix( ((2,3), (3, 5)) )
a[0,:].min()
# Out:
# 2

# %%
#Investigo acerca del dtype del elemento a 
a.dtype
# Out:
# dtype('int32')

# %%
#Dado que tanto la edad como la expriencia vienen dadas en enteros, cambio de float a int
X_train['n_experience']=np.asarray(X_train['n_experience'], dtype=int)
X_train['n_age']=np.asarray(X_train['n_age'], dtype=int)

# %%
#Verifico el cambio supra mencionado
X_train['n_experience'].dtype, X_train['n_age'].dtype
# Out:
# (dtype('int32'), dtype('int32'))

# %%
#Armo una matriz con el vector X_train['n_age'] para tenerlo a resguardo y poder copiarlo a mano si hicera falta
Xtrain_3=np.matrix( X_train['n_age'])
#Pruebo que los métodos de min y max funcionen
Xtrain_3.min(),Xtrain_3.max()
# Out:
# (23, 45)

# %%
#Lo mismo para para X_train['n_experience']
Xtrain_4=np.matrix( X_train['n_experience'])
Xtrain_4[0,:].min(), Xtrain_4[0,:].max()
# Out:
# (2, 16)

# %%
#Imprimo ambos
Xtrain_3,Xtrain_4
# Out:
# (matrix([[27, 33, 25, 35, 35, 24, 44, 35, 45, 44, 27, 44, 34, 35, 41, 28,
#           34, 25, 45, 34, 23, 34, 23, 24, 35, 25, 35, 27, 33, 35, 25, 27,
#           35, 27, 44, 24, 44, 28, 23, 44, 45, 34, 33, 35, 34, 44, 33, 28,
#           35, 27, 28, 27, 34, 35, 41, 44, 41, 35, 44, 34, 27, 35, 45, 35,
#           44, 33, 35, 24, 44, 34, 24, 35, 33, 41, 27, 28, 28, 27, 44, 27,
#           34, 45, 23, 27]]),
#  matrix([[ 3,  7,  2,  3,  3,  2, 11,  3, 16, 11,  3, 11,  5,  3, 12,  4,
#            4,  2, 16,  4,  3,  5,  3,  2,  3,  2,  3,  3,  7,  6,  2,  3,
#            3,  3, 11,  2, 11,  4,  3, 11, 16,  5,  7,  3,  4, 11,  7,  4,
#            3,  3,  4,  3,  4,  6, 12, 11, 12,  6, 11,  5,  3,  3, 16,  3,
#           11,  7,  6,  2, 11,  5,  2,  6,  7, 12,  3,  4,  4,  3, 11,  3,
#            4, 16,  3,  3]]))

# %%
 Xtrain_3.shape, Xtrain_4.shape
# Out:
# ((1, 84), (1, 84))

# %%
#Defino una matriz nula 
Xtrain=np.zeros((2,84))
#La lleno con mis vectores 
Xtrain[0,:]= Xtrain_3
Xtrain[1,:]= Xtrain_4

# %%
Xtrain[0,:].min(),Xtrain[1,:].min()
# Out:
# (23.0, 2.0)

# %% [markdown]
# ### Ni así!

# %%
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# %%
print(classification_report(y_train, y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        47
#          1.0       1.00      1.00      1.00        37
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84

# %%
print(classification_report(y_test, y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        14
#          1.0       1.00      1.00      1.00         8
#
#     accuracy                           1.00        22
#    macro avg       1.00      1.00      1.00        22
# weighted avg       1.00      1.00      1.00        22

# %% [markdown]
# Puede dar tan bien?

# %%
utils.plot_decision_boundary(lambda x: model.predict(x), Xtrain, y_train.T)

# %% [markdown]
# # Fin del asunto!

# %% [markdown]
# ## 2. K Nearest Neighbors ó K Vecinos Más Cercanos

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors=3)
model.fit(X, y)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                      weights='uniform')

# %%
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# %%
print(classification_report(y_train, y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        47
#          1.0       1.00      1.00      1.00        37
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84

# %%
print(classification_report(y_test, y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        14
#          1.0       1.00      1.00      1.00         8
#
#     accuracy                           1.00        22
#    macro avg       1.00      1.00      1.00        22
# weighted avg       1.00      1.00      1.00        22

# %% [markdown]
# ## 3. Regresión Lineal.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
regr = LinearRegression()

# %%
regr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_train_pred = regr.predict(X_train)
y_test_pred = regr.predict(X_test)

# %%
# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print("Mean squared error: %.2f"
      % mean_squared_error(y_test, y_test_pred))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(y_test, y_test_pred))

# Plot outputs
plt.scatter(X_train['n_experience'], y_train,  color='green')
plt.scatter(X_test['n_experience'], y_test,  color='black')
plt.plot(X_test['n_experience'], y_test_pred, color='blue', linewidth=3)

plt.xticks(())
plt.yticks(())

plt.show()
# Out:
# Coefficients:
#  [0.01323351 0.07885121]
# Mean squared error: 0.03
# Variance score: 0.87

# %% [markdown]
# ## 4. Regresión Logística.

# %%
model = make_pipeline(StandardScaler(),
                    SGDClassifier(loss="log", eta0=1, learning_rate="constant", penalty=None))
model.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('standardscaler',
#                  StandardScaler(copy=True, with_mean=True, with_std=True)),
#                 ('sgdclassifier',
#                  SGDClassifier(alpha=0.0001, average=False, class_weight=None,
#                                early_stopping=False, epsilon=0.1, eta0=1,
#                                fit_intercept=True, l1_ratio=0.15,
#                                learning_rate='constant', loss='log',
#                                max_iter=1000, n_iter_no_change=5, n_jobs=None,
#                                penalty=None, power_t=0.5, random_state=None,
#                                shuffle=True, tol=0.001, validation_fraction=0.1,
#                                verbose=0, warm_start=False))],
#          verbose=False)

# %%
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# %%
print(classification_report(y_train, y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        47
#          1.0       1.00      1.00      1.00        37
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84

# %%
print(classification_report(y_test, y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        14
#          1.0       1.00      1.00      1.00         8
#
#     accuracy                           1.00        22
#    macro avg       1.00      1.00      1.00        22
# weighted avg       1.00      1.00      1.00        22

# %%
# Plot outputs
#plt.scatter(X_train['n_experience'], y_train,  color='green')
plt.scatter(X_test['n_experience'], y_test,  color='black')
plt.scatter(X_test['n_experience'], y_test_pred, color='blue')

plt.xticks(())
plt.yticks(())

plt.show()
